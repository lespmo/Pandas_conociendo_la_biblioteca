# %% [markdown]
# <a href="https://colab.research.google.com/github/ahcamachod/2061-pandas-conociendo-la-biblioteca/blob/aula-2/inmuebles_cdmx.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Pandas: Conociendo la biblioteca**

# %% [markdown]
# ## **Importando la base de datos**

# %%
# haciendo los pasos de trello
import pandas as pd

url_aluiler_cdmx = 'https://gist.githubusercontent.com/ahcamachod/a572cfcc2527046db93101f88011b26e/raw/ffb13f45a79d31223e645611a119397dd127ee3c/alquiler.csv'

pd.read_csv(url_aluiler_cdmx)
# Out:
#       Tipo;Colonia;Habitaciones;Garages;Suites;Area;Valor;Condominio;Impuesto
# 0          Cocineta;Condesa;1;0;0;40;5950.0;1750.0;210.0
# 1                       Casa;Polanco;2;0;1;100;24500.0;;
# 2      Conjunto Comercial/Sala;Santa Fe;0;4;0;150;182...
# 3      Departamento;Centro Histórico;1;0;0;15;2800.0;...
# 4          Departamento;Del Valle;1;0;0;48;2800.0;805.0;
# ...                                                  ...
# 25116  Cochera/Estacionamiento;Centro Histórico;0;0;0...
# 25117  Cocineta;Centro Histórico;0;0;0;27;2800.0;1225...
# 25118  Departamento;Mixcoac;2;1;0;48;4900.0;1781.5;129.5
# 25119  Departamento;Lomas de Chapultepec;2;0;0;70;105...
# 25120  Conjunto Comercial/Sala;Centro Histórico;0;0;0...
#
# [25121 rows x 1 columns]

# %%
from posixpath import sep
pd.read_csv(url_aluiler_cdmx, sep=';')
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 0                     Cocineta               Condesa             1        0
# 1                         Casa               Polanco             2        0
# 2      Conjunto Comercial/Sala              Santa Fe             0        4
# 3                 Departamento      Centro Histórico             1        0
# 4                 Departamento             Del Valle             1        0
# ...                        ...                   ...           ...      ...
# 25116  Cochera/Estacionamiento      Centro Histórico             0        0
# 25117                 Cocineta      Centro Histórico             0        0
# 25118             Departamento               Mixcoac             2        1
# 25119             Departamento  Lomas de Chapultepec             2        0
# 25120  Conjunto Comercial/Sala      Centro Histórico             0        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# ...

# %%
datos_alquiler_cdmx = pd.read_csv(url_aluiler_cdmx, sep=';')
datos_alquiler_cdmx
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 0                     Cocineta               Condesa             1        0
# 1                         Casa               Polanco             2        0
# 2      Conjunto Comercial/Sala              Santa Fe             0        4
# 3                 Departamento      Centro Histórico             1        0
# 4                 Departamento             Del Valle             1        0
# ...                        ...                   ...           ...      ...
# 25116  Cochera/Estacionamiento      Centro Histórico             0        0
# 25117                 Cocineta      Centro Histórico             0        0
# 25118             Departamento               Mixcoac             2        1
# 25119             Departamento  Lomas de Chapultepec             2        0
# 25120  Conjunto Comercial/Sala      Centro Histórico             0        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# ...

# %%
#muestra las primeras 5 filas de los datos datos_alquiler_cdmx
datos_alquiler_cdmx.head()
# Out:
#                       Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                 Cocineta           Condesa             1        0       0
# 1                     Casa           Polanco             2        0       1
# 2  Conjunto Comercial/Sala          Santa Fe             0        4       0
# 3             Departamento  Centro Histórico             1        0       0
# 4             Departamento         Del Valle             1        0       0
#
#    Area    Valor  Condominio  Impuesto
# 0    40   5950.0      1750.0     210.0
# 1   100  24500.0         NaN       NaN
# 2   150  18200.0     14070.0    3888.5
# 3    15   2800.0      1365.0      70.0
# 4    48   2800.0       805.0       NaN

# %%
# muestra las cinco ultimas filas de los datos datos_alquiler_cdmx
datos_alquiler_cdmx.tail()
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 25116  Cochera/Estacionamiento      Centro Histórico             0        0
# 25117                 Cocineta      Centro Histórico             0        0
# 25118             Departamento               Mixcoac             2        1
# 25119             Departamento  Lomas de Chapultepec             2        0
# 25120  Conjunto Comercial/Sala      Centro Histórico             0        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# 25116       0   755  49000.0         NaN       NaN
# 25117       0    27   2800.0      1225.0      87.5
# 25118       0    48   4900.0      1781.5     129.5
# 25119       0    70  10500.0      2660.0       NaN
# 25120       0   250  22750.0     14721.0    3881.5

# %%
#muestra las primeras 10 filas de los datos datos_alquiler_cdmx
datos_alquiler_cdmx.head(10)
# Out:
#                       Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                 Cocineta           Condesa             1        0       0
# 1                     Casa           Polanco             2        0       1
# 2  Conjunto Comercial/Sala          Santa Fe             0        4       0
# 3             Departamento  Centro Histórico             1        0       0
# 4             Departamento         Del Valle             1        0       0
# 5       Casa de Condominio          Santa Fe             5        4       5
# 6  Conjunto Comercial/Sala  Centro Histórico             0        3       0
# 7             Departamento  Centro Histórico             1        0       0
# 8             Departamento           Condesa             1        0       1
# 9                 Cocineta           Condesa             1        0       0
#
#    Area     Valor  Condominio  Impuesto
# 0    40    5950.0      1750.0     210.0
# 1   100   24500.0         NaN       NaN
# ...

# %%
#muestra 10 filas de los datos datos_alquiler_cdmx seleccionados aleatoriamente
datos_alquiler_cdmx.sample(10)
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 23550             Departamento               Condesa             4        1
# 24593                     Casa    Villa de Guadalupe             3        5
# 16810  Conjunto Comercial/Sala  Lomas de Chapultepec             0        2
# 4544              Departamento                  Roma             2        1
# 20544             Departamento              Narvarte             2        0
# 479    Conjunto Comercial/Sala              Santa Fe             0       14
# 21705             Departamento              Coyoacán             2        0
# 13985             Departamento       Villa de Cortés             2        0
# 7203   Conjunto Comercial/Sala      Centro Histórico             0        0
# 3010        Casa de Condominio             San Ángel             3        1
#
#        Suites  Area     Valor  Condominio  Impuesto
# 23550       1   223   17500.0      6440.0    1319.5
# ...

# %%
# saber que tipo de datos e s datos datos_alquiler_cdmx
type(datos_alquiler_cdmx)
# Out:
# pandas.core.frame.DataFrame

# %%
datos_alquiler_cdmx.info
# Out:
# <bound method DataFrame.info of                           Tipo               Colonia  Habitaciones  Garages  \
# 0                     Cocineta               Condesa             1        0
# 1                         Casa               Polanco             2        0
# 2      Conjunto Comercial/Sala              Santa Fe             0        4
# 3                 Departamento      Centro Histórico             1        0
# 4                 Departamento             Del Valle             1        0
# ...                        ...                   ...           ...      ...
# 25116  Cochera/Estacionamiento      Centro Histórico             0        0
# 25117                 Cocineta      Centro Histórico             0        0
# 25118             Departamento               Mixcoac             2        1
# 25119             Departamento  Lomas de Chapultepec             2        0
# 25120  Conjunto Comercial/Sala      Centro Histórico             0        0
#
# ...

# %%
datos_alquiler_cdmx.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25121 entries, 0 to 25120
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          25121 non-null  object
#  1   Colonia       25121 non-null  object
#  2   Habitaciones  25121 non-null  int64
#  3   Garages       25121 non-null  int64
#  4   Suites        25121 non-null  int64
#  5   Area          25121 non-null  int64
#  6   Valor         25107 non-null  float64
#  7   Condominio    22495 non-null  float64
#  8   Impuesto      18037 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 1.7+ MB

# %% [markdown]
# ## **Exploración inicial de los datos**

# %%
#tomar muestra aleatoria de los datos
datos_alquiler_cdmx.sample(5)
# Out:
#                           Tipo   Colonia  Habitaciones  Garages  Suites  Area  \
# 21735                 Cocineta   Condesa             1        0       0    30
# 1330              Departamento   Condesa             3        0       0   128
# 18120             Departamento   Condesa             3        2       1   126
# 14805  Conjunto Comercial/Sala  Santa Fe             0        0       0     6
# 3444              Departamento   Condesa             3        1       0   110
#
#          Valor  Condominio  Impuesto
# 21735   4025.0       973.0      87.5
# 1330   10500.0      4200.0     437.5
# 18120   9800.0      5614.0     857.5
# 14805  14507.5         NaN       NaN
# 3444    8750.0      4725.0     455.0

# %%
#atributo shape para el tamaños de la matriz data frama
datos_alquiler_cdmx.shape
# Out:
# (25121, 9)

# %%
# nos muestra los titulos del encabezado
datos_alquiler_cdmx.columns
# Out:
# Index(['Tipo', 'Colonia', 'Habitaciones', 'Garages', 'Suites', 'Area', 'Valor',
#        'Condominio', 'Impuesto'],
#       dtype='object')

# %%
#informacion de los datos del dataframe
datos_alquiler_cdmx.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25121 entries, 0 to 25120
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          25121 non-null  object
#  1   Colonia       25121 non-null  object
#  2   Habitaciones  25121 non-null  int64
#  3   Garages       25121 non-null  int64
#  4   Suites        25121 non-null  int64
#  5   Area          25121 non-null  int64
#  6   Valor         25107 non-null  float64
#  7   Condominio    22495 non-null  float64
#  8   Impuesto      18037 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 1.7+ MB

# %%
#extraer la columna tipo del data frame
datos_alquiler_cdmx['Tipo']
# Out:
# 0                       Cocineta
# 1                           Casa
# 2        Conjunto Comercial/Sala
# 3                   Departamento
# 4                   Departamento
#                   ...
# 25116    Cochera/Estacionamiento
# 25117                   Cocineta
# 25118               Departamento
# 25119               Departamento
# 25120    Conjunto Comercial/Sala
# Name: Tipo, Length: 25121, dtype: object

# %%
#quiero visualizar dos columnas y el prametro es una lista es decir dos columnas
datos_alquiler_cdmx[['Habitaciones','Valor']]
# Out:
#        Habitaciones    Valor
# 0                 1   5950.0
# 1                 2  24500.0
# 2                 0  18200.0
# 3                 1   2800.0
# 4                 1   2800.0
# ...             ...      ...
# 25116             0  49000.0
# 25117             0   2800.0
# 25118             2   4900.0
# 25119             2  10500.0
# 25120             0  22750.0
#
# [25121 rows x 2 columns]

# %% [markdown]
# La biblioteca Pandas es una de las herramientas más utilizadas por los científicos de datos para el análisis y manipulación de datos. Proporciona dos estructuras de datos principales, el DataFrame y la Serie, que se utilizan ampliamente para representar y manipular datos tabulares en Python.
#
#
# La Serie es una estructura de datos unidimensional que puede almacenar cualquier tipo de datos, etiquetados con índices.
#
# Muy bien, una Serie es básicamente una matriz unidimensional etiquetada que puede almacenar cualquier tipo de datos. Cada elemento de la Serie está etiquetado con un índice que se puede utilizar para acceder y manipular sus valores.
#
# Un DataFrame es una estructura de datos asociativa que almacena pares de clave-valor.
#
# Excelente, un DataFrame es básicamente una estructura de datos bidimensional que se utiliza para almacenar información estructurada en forma de tabla.

# %% [markdown]
# #EJERCICIO DE TERIA CAPITULO 1 SECCION 9

# %% [markdown]
# Para practicar los métodos aprendidos a lo largo de esta lección y aprender nuevos, realizaremos algunos análisis utilizando un archivo CSV diferente: alumnos.csv.
#
# https://gist.githubusercontent.com/ahcamachod/807a2c1cf6c19108b2b701ea1791ab45/raw/fb84f8b2d8917a89de26679eccdbc8f9c1d2e933/alumnos.csv
#
# Importa el archivo alumnos.csv y almacena su contenido en un DataFrame de Pandas.
#
# Visualiza las primeras 7 filas del DataFrame y las últimas 5.
#
# Verifica la cantidad de filas y columnas en este DataFrame.
#
# Explora las columnas del DataFrame y analiza los tipos de datos presentes en cada columna.
#
# Extra: Calcula algunas estadísticas descriptivas básicas de los datos en el DataFrame (media, desviación estándar, etc.). Pista: busca el método "describe".
#
# Si necesitas ayuda, en la sección "Opinión del Instructor" puedes encontrar algunas formas de resolver los desafíos propuestos anteriormente.

# %%
# INICIO DEL EJERCICIO ALUMNOS
# IMPORTANTO DATOS
import pandas as pd
url_ejerc_alumnos = 'https://gist.githubusercontent.com/ahcamachod/807a2c1cf6c19108b2b701ea1791ab45/raw/fb84f8b2d8917a89de26679eccdbc8f9c1d2e933/alumnos.csv'
datos_ejerc_alumnos = pd.read_csv(url_ejerc_alumnos)

# %%
# VISUALIZACION DE DATOS
datos_ejerc_alumnos.head(7)
# Out:
#     Nombre  Edad  Nota Aprobado
# 0  Alberto    20   7.5     True
# 1      Ana    18   NaN    False
# 2   Camila    27   2.5    False
# 3    David    18   5.0    False
# 4    Brian    21  10.0     True
# 5    Bruna    23   NaN    False
# 6  Daniela    21   7.0     True

# %%
# VISUALIZACION DE DATOS
datos_ejerc_alumnos.tail(7)
# Out:
#       Nombre  Edad  Nota   Aprobado
# 11   Ignacio    24   4.5      False
# 12  Stephany    26  10.0       True
# 13    Miriam    25   9.0       True
# 14     Pablo    37   NaN      False
# 15    Milena    29   7.0       True
# 16     Lucas    33   NaN      False
# 17     Nadia    34   8.0  Verdadero

# %%
#VISUALIZACION DE UNA MUESTRA ALEATORIA
#datos_ejerc_alumnos.shape()

# %%
type(datos_ejerc_alumnos)
# Out:
# pandas.core.frame.DataFrame

# %%
# informacion de la forma 18 filas 4 columnas
datos_ejerc_alumnos.shape
# Out:
# (18, 4)

# %%
# ver informacion del geader encabezado o los nombres de la scolumnas
datos_ejerc_alumnos.columns
# Out:
# Index(['Nombre', 'Edad', 'Nota', 'Aprobado'], dtype='object')

# %%
# infromacion de los datos del datafram
datos_ejerc_alumnos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Nombre    18 non-null     object
#  1   Edad      18 non-null     int64
#  2   Nota      12 non-null     float64
#  3   Aprobado  18 non-null     object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 708.0+ bytes

# %%
# visualizar una de las cumnas
datos_ejerc_alumnos['Nombre']
# Out:
# 0      Alberto
# 1          Ana
# 2       Camila
# 3        David
# 4        Brian
# 5        Bruna
# 6      Daniela
# 7       Carlos
# 8       Alicia
# 9       Victor
# 10      Danilo
# 11     Ignacio
# 12    Stephany
# 13      Miriam
# 14       Pablo
# 15      Milena
# 16       Lucas
# 17       Nadia
# Name: Nombre, dtype: object

# %%
# visualizar una de las cumnas
datos_ejerc_alumnos['Aprobado']
# Out:
# 0          True
# 1         False
# 2         False
# 3         False
# 4          True
# 5         False
# 6          True
# 7         False
# 8         False
# 9         False
# 10        False
# 11        False
# 12         True
# 13         True
# 14        False
# 15         True
# 16        False
# 17    Verdadero
# Name: Aprobado, dtype: object

# %%
# visualizar dos columnas
datos_ejerc_alumnos[['Edad','Nota']]
# Out:
#     Edad  Nota
# 0     20   7.5
# 1     18   NaN
# 2     27   2.5
# 3     18   5.0
# 4     21  10.0
# 5     23   NaN
# 6     21   7.0
# 7     19   6.0
# 8     35   5.6
# 9     28   NaN
# 10    21   NaN
# 11    24   4.5
# 12    26  10.0
# 13    25   9.0
# 14    37   NaN
# 15    29   7.0
# 16    33   NaN
# 17    34   8.0

# %%
# tipos de dato del data frame
datos_ejerc_alumnos.dtypes
# Out:
# Nombre       object
# Edad          int64
# Nota        float64
# Aprobado     object
# dtype: object

# %%
# funcion describe de pandas
datos_ejerc_alumnos.describe()
# Out:
#             Edad       Nota
# count  18.000000  12.000000
# mean   25.500000   6.841667
# std     6.070662   2.264532
# min    18.000000   2.500000
# 25%    21.000000   5.450000
# 50%    24.500000   7.000000
# 75%    28.750000   8.250000
# max    37.000000  10.000000

# %%
# funcion describe de pandas
datos_ejerc_alumnos.describe()
# Out:
#             Edad       Nota
# count  18.000000  12.000000
# mean   25.500000   6.841667
# std     6.070662   2.264532
# min    18.000000   2.500000
# 25%    21.000000   5.450000
# 50%    24.500000   7.000000
# 75%    28.750000   8.250000
# max    37.000000  10.000000

# %% [markdown]
# ## **Demandas de ML**

# %% [markdown]
# ###**aNALIIS EXPLORATORIO DE LOS DATOS**

# %% [markdown]
# #### ¿Cuáles son los valores promedio de alquiler por tipo de propiedad?

# %%
# nbuevamente un .head
datos_alquiler_cdmx.head()
# Out:
#                       Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                 Cocineta           Condesa             1        0       0
# 1                     Casa           Polanco             2        0       1
# 2  Conjunto Comercial/Sala          Santa Fe             0        4       0
# 3             Departamento  Centro Histórico             1        0       0
# 4             Departamento         Del Valle             1        0       0
#
#    Area    Valor  Condominio  Impuesto
# 0    40   5950.0      1750.0     210.0
# 1   100  24500.0         NaN       NaN
# 2   150  18200.0     14070.0    3888.5
# 3    15   2800.0      1365.0      70.0
# 4    48   2800.0       805.0       NaN

# %%
#calculando el promedio de los valores con la funcion mean
#datos_alquiler_cdmx.mean()

# %%
#calculando el promedio de los valores con la funcion mean
#nos da el valor promedio de la columna Valor y se requiere segun el tipo de propiedad
datos_alquiler_cdmx['Valor'].mean()
# Out:
# np.float64(36885.05048392878)

# %%
#Visualizar Agrupando le saca a cada uno de los tipos el promedio
#datos_alquiler_cdmx.groupby('Tipo').mean()
#datos_alquiler_cdmx.groupby('Tipo').mean(numeric_only=True)

# %%
#Visualizar Agrupando le saca a cada uno de los tipos el promedio
datos_alquiler_cdmx.groupby('Tipo').mean(numeric_only=True)
# Out:
#                             Habitaciones    Garages     Suites          Area  \
# Tipo
# Casa                            3.359633   1.897248   1.438532    289.943119
# Casa Comercial                  1.801980   2.118812   0.257426    370.277228
# Casa de Condominio              4.319672   3.555738   3.247541    566.303279
# Casa de Vecindad                1.974684   0.379747   0.215190     79.981013
# Cochera/Estacionamiento         0.064935   1.376623   0.000000     18.662338
# Cocineta                        0.836088   0.020661   0.041322     29.090909
# Conjunto Comercial/Sala         0.047175   2.686323   0.000352    236.323711
# Departamento                    2.504199   1.256367   0.891899    124.014292
# Departamento en Hotel           1.419780   0.969231   0.758242     65.848352
# Edificio Completo               0.405530  11.175115   0.027650   1717.271889
# Estudio                         0.500000   0.250000   0.000000    103.250000
# ...

# %%
#Visualizar Agrupando le saca a cada uno de los tipos el promedio y le quito el numerico porque solo a la columna valor
datos_alquiler_cdmx.groupby('Tipo')['Valor'].mean()
# Out:
# Tipo
# Casa                           31453.177064
# Casa Comercial                 54735.841584
# Casa de Condominio             51428.609836
# Casa de Vecindad                5961.740506
# Cochera/Estacionamiento         6995.454545
# Cocineta                        4425.856061
# Conjunto Comercial/Sala        57675.214550
# Departamento                   18683.269431
# Departamento en Hotel          16285.430769
# Edificio Completo             409418.080645
# Estudio                         8400.000000
# Galpón/Depósito/Almacén       299984.140138
# Hotel                          87500.000000
# Industria                     420000.000000
# Loft                            9924.526316
# Loteo/Condominio               92166.666667
# Posada/Chalé                    5180.000000
# Rancho                         38014.375000
# Terreno Estándar              135364.444444
# Tienda en Centro Comercial     32556.785714
# Tienda/Salón                   56263.544252
# ...

# %%
#Visualizar Agrupando le saca a cada uno de los tipos el promedio y le quito el numerico porque solo a la columna valor
#ademas de organizarlos con sort_values
#datos_alquiler_cdmx.groupby('Tipo')['Valor'].mean().sort_values('Valor')

# %%
#Visualizar Agrupando le saca a cada uno de los tipos el promedio y le quito el numerico porque solo a la columna valor
#ademas de organizarlos con sort_values
#la columna valor debe ser entre poarentesis cuadrados porque antes estaba como serie series, debe ir como datafrqame
datos_alquiler_cdmx.groupby('Tipo')[['Valor']].mean().sort_values('Valor')
# Out:
#                                     Valor
# Tipo
# Cocineta                      4425.856061
# Posada/Chalé                  5180.000000
# Casa de Vecindad              5961.740506
# Cochera/Estacionamiento       6995.454545
# Estudio                       8400.000000
# Loft                          9924.526316
# Departamento en Hotel        16285.430769
# Departamento                 18683.269431
# Casa                         31453.177064
# Tienda en Centro Comercial   32556.785714
# Rancho                       38014.375000
# Casa de Condominio           51428.609836
# Casa Comercial               54735.841584
# Tienda/Salón                 56263.544252
# Conjunto Comercial/Sala      57675.214550
# Hotel                        87500.000000
# Loteo/Condominio             92166.666667
# Terreno Estándar            135364.444444
# Galpón/Depósito/Almacén     299984.140138
# Edificio Completo           409418.080645
# Industria                   420000.000000

# %%
# almacenando el anterior calculo de promedios por tipo de vivienda en una variable
#ademas de graficarlo con barras horizontales el tamaño y el color
df_tipo_precio = datos_alquiler_cdmx.groupby('Tipo')[['Valor']].mean().sort_values('Valor')

# %%
df_tipo_precio
# Out:
#                                     Valor
# Tipo
# Cocineta                      4425.856061
# Posada/Chalé                  5180.000000
# Casa de Vecindad              5961.740506
# Cochera/Estacionamiento       6995.454545
# Estudio                       8400.000000
# Loft                          9924.526316
# Departamento en Hotel        16285.430769
# Departamento                 18683.269431
# Casa                         31453.177064
# Tienda en Centro Comercial   32556.785714
# Rancho                       38014.375000
# Casa de Condominio           51428.609836
# Casa Comercial               54735.841584
# Tienda/Salón                 56263.544252
# Conjunto Comercial/Sala      57675.214550
# Hotel                        87500.000000
# Loteo/Condominio             92166.666667
# Terreno Estándar            135364.444444
# Galpón/Depósito/Almacén     299984.140138
# Edificio Completo           409418.080645
# Industria                   420000.000000

# %%
df_tipo_precio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21 entries, Cocineta to Industria
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Valor   21 non-null     float64
# dtypes: float64(1)
# memory usage: 336.0+ bytes

# %%
#df_tipo_precio.Tipo.unique()

# %%
# almacenando el anterior calculo de promedios por tipo de vivienda en una variable
#ademas de graficarlo con barras horizontales el tamaño y el color
df_tipo_precio.plot(kind='barh',figsize=(12,8),color='purple')
# Out:
# <Axes: ylabel='Tipo'>

# %%
df_tipo_precio
# Out:
#                                     Valor
# Tipo
# Cocineta                      4425.856061
# Posada/Chalé                  5180.000000
# Casa de Vecindad              5961.740506
# Cochera/Estacionamiento       6995.454545
# Estudio                       8400.000000
# Loft                          9924.526316
# Departamento en Hotel        16285.430769
# Departamento                 18683.269431
# Casa                         31453.177064
# Tienda en Centro Comercial   32556.785714
# Rancho                       38014.375000
# Casa de Condominio           51428.609836
# Casa Comercial               54735.841584
# Tienda/Salón                 56263.544252
# Conjunto Comercial/Sala      57675.214550
# Hotel                        87500.000000
# Loteo/Condominio             92166.666667
# Terreno Estándar            135364.444444
# Galpón/Depósito/Almacén     299984.140138
# Edificio Completo           409418.080645
# Industria                   420000.000000

# %% [markdown]
# #**EJERCICIO TEORICO CAPITULO  2 NUMERAL 3**

# %%
#EJERCICIO DEL METODO groupby
# crando el data frame con codigo
import pandas as pd

df_ejercicio = pd.DataFrame({
   'Animal': ['Perro', 'Gato', 'Elefante', 'Perro', 'Gato', 'Elefante'],
   'Color': ['Negro', 'Blanco', 'Gris', 'Marrón', 'Negro', 'Marrón'],
   'Cantidad': [2, 3, 1, 4, 2, 2]
})
df_ejercicio
# Out:
#      Animal   Color  Cantidad
# 0     Perro   Negro         2
# 1      Gato  Blanco         3
# 2  Elefante    Gris         1
# 3     Perro  Marrón         4
# 4      Gato   Negro         2
# 5  Elefante  Marrón         2

# %%
#Aquí tenemos un DataFrame con datos sobre algunos animales. Usaremos groupby para agrupar los datos por tipo de animal y realizar la suma de la columna "Cantidad" para obtener el total de cada tipo de animal
df_ejercicio.groupby('Animal').sum(numeric_only=True)
# Out:
#           Cantidad
# Animal
# Elefante         3
# Gato             5
# Perro            6

# %%
# También podemos usar el método groupby para agrupar datos por múltiples columnas
# Por ejemplo, agrupemos por tipo de animal y también por color, y realicemos la suma de la columna "Cantidad":
df_ejercicio.groupby(['Animal', 'Color'])[['Cantidad']].sum()
# Out:
#                  Cantidad
# Animal   Color
# Elefante Gris           1
#          Marrón         2
# Gato     Blanco         3
#          Negro          2
# Perro    Marrón         4
#          Negro          2

# %% [markdown]
# #**FIN DE EJERCICIO**

# %% [markdown]
# # **RETOMANDO INMUEBLES**

# %%
#UNA FORMA DE VER TODOS LOS TIPO DE INMUEBLE QUE TIOEN EL DATA FRAME
datos_alquiler_cdmx.Tipo.unique()
# Out:
# array(['Cocineta', 'Casa', 'Conjunto Comercial/Sala', 'Departamento',
#        'Casa de Condominio', 'Edificio Completo', 'Departamento en Hotel',
#        'Tienda/Salón', 'Casa Comercial', 'Casa de Vecindad',
#        'Terreno Estándar', 'Cochera/Estacionamiento', 'Loft',
#        'Galpón/Depósito/Almacén', 'Tienda en Centro Comercial', 'Rancho',
#        'Posada/Chalé', 'Estudio', 'Hotel', 'Loteo/Condominio',
#        'Industria'], dtype=object)

# %%
#LISTA DE INMUEBELS NETAMENTE COMERCIALES
Inmuebles_Comerciales_ = ['Conjunto Comercial/Sala', 'Edificio Completo', 'Tienda/Salón', 'Casa Comercial', 'Terreno Estándar', 'Cochera/Estacionamiento',
       'Galpón/Depósito/Almacén', 'Tienda en Centro Comercial', 'Hotel', 'Loteo/Condominio',
       'Industria']
Inmuebles_Comerciales_
# Out:
# ['Conjunto Comercial/Sala',
#  'Edificio Completo',
#  'Tienda/Salón',
#  'Casa Comercial',
#  'Terreno Estándar',
#  'Cochera/Estacionamiento',
#  'Galpón/Depósito/Almacén',
#  'Tienda en Centro Comercial',
#  'Hotel',
#  'Loteo/Condominio',
#  'Industria']

# %%
#vamos a filtrar los datos caule y ciuantos son inmuebles industriales con query
datos_alquiler_cdmx.query('@Inmuebles_Comerciales_ in Tipo')
# Out:
#                           Tipo           Colonia  Habitaciones  Garages  \
# 2      Conjunto Comercial/Sala          Santa Fe             0        4
# 6      Conjunto Comercial/Sala  Centro Histórico             0        3
# 11           Edificio Completo              Roma             0        0
# 24     Conjunto Comercial/Sala          Santa Fe             0        1
# 26     Conjunto Comercial/Sala  Centro Histórico             0        5
# ...                        ...               ...           ...      ...
# 25107  Conjunto Comercial/Sala          Santa Fe             0        1
# 25110  Conjunto Comercial/Sala  Centro Histórico             0        0
# 25112  Conjunto Comercial/Sala  Centro Histórico             0        0
# 25116  Cochera/Estacionamiento  Centro Histórico             0        0
# 25120  Conjunto Comercial/Sala  Centro Histórico             0        0
#
#        Suites  Area     Valor  Condominio  Impuesto
# ...

# %%
#vamos a filtrar los datos descartando los inmuebles industriales con query
datos_alquiler_cdmx.query('@Inmuebles_Comerciales_ not in Tipo')
# Out:
#                      Tipo               Colonia  Habitaciones  Garages  \
# 0                Cocineta               Condesa             1        0
# 1                    Casa               Polanco             2        0
# 3            Departamento      Centro Histórico             1        0
# 4            Departamento             Del Valle             1        0
# 5      Casa de Condominio              Santa Fe             5        4
# ...                   ...                   ...           ...      ...
# 25114        Departamento              Narvarte             1        0
# 25115  Casa de Condominio              Santa Fe             5        3
# 25117            Cocineta      Centro Histórico             0        0
# 25118        Departamento               Mixcoac             2        1
# 25119        Departamento  Lomas de Chapultepec             2        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# 0           0    40   5950.0      1750.0     210.0
# ...

# %%
#comprobamos con almacenamiento en un data frame y hacerle un df con el head
df_inm_residenciales = datos_alquiler_cdmx.query('@Inmuebles_Comerciales_ not in Tipo')
df_inm_residenciales.head()
# Out:
#                  Tipo           Colonia  Habitaciones  Garages  Suites  Area  \
# 0            Cocineta           Condesa             1        0       0    40
# 1                Casa           Polanco             2        0       1   100
# 3        Departamento  Centro Histórico             1        0       0    15
# 4        Departamento         Del Valle             1        0       0    48
# 5  Casa de Condominio          Santa Fe             5        4       5   750
#
#      Valor  Condominio  Impuesto
# 0   5950.0      1750.0     210.0
# 1  24500.0         NaN       NaN
# 3   2800.0      1365.0      70.0
# 4   2800.0       805.0       NaN
# 5  77000.0         NaN       NaN

# %%
# luego de filtrar las residenciales se vuelve a ejecutar el comnado de promedios y se hace la grafica
dfTipoPrecio = df_inm_residenciales.groupby('Tipo')[['Valor']].mean().sort_values('Valor')
dfTipoPrecio.plot(kind='barh',figsize=(12,8),color='purple')
# Out:
# <Axes: ylabel='Tipo'>

# %% [markdown]
# ### Porcentaje de cada tipo de inmueble presente en la base de datos

# %% [markdown]
# supongamos que el equipo de aprendizaje automático (ML) ha realizado la siguiente solicitud:
#
#
#
#
# df.query('Suites >= 1')
#
#
#
# Excelente! Al pasar la expresión 'Suites >= 1' al método query, especificamos que queremos seleccionar las filas en las que la columna "Suites" tiene un valor mayor o igual a 1.

# %% [markdown]
# Fins de la base de datos

# %% [markdown]
# ### Porcentaje de cada tipo de inmueble presente en la base de datos

# %%
#verificando la lista de los inmuebles residenciales
dfTipoPrecio
# Out:
#                               Valor
# Tipo
# Cocineta                4425.856061
# Posada/Chalé            5180.000000
# Casa de Vecindad        5961.740506
# Estudio                 8400.000000
# Loft                    9924.526316
# Departamento en Hotel  16285.430769
# Departamento           18683.269431
# Casa                   31453.177064
# Rancho                 38014.375000
# Casa de Condominio     51428.609836

# %%
dfTipoPrecio.head
# Out:
# <bound method NDFrame.head of                               Valor
# Tipo
# Cocineta                4425.856061
# Posada/Chalé            5180.000000
# Casa de Vecindad        5961.740506
# Estudio                 8400.000000
# Loft                    9924.526316
# Departamento en Hotel  16285.430769
# Departamento           18683.269431
# Casa                   31453.177064
# Rancho                 38014.375000
# Casa de Condominio     51428.609836>

# %%
dfTipoPrecio.index.unique()
# Out:
# Index(['Cocineta', 'Posada/Chalé', 'Casa de Vecindad', 'Estudio', 'Loft',
#        'Departamento en Hotel', 'Departamento', 'Casa', 'Rancho',
#        'Casa de Condominio'],
#       dtype='object', name='Tipo')

# %%
dfTipoPrecio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, Cocineta to Casa de Condominio
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Valor   10 non-null     float64
# dtypes: float64(1)
# memory usage: 460.0+ bytes

# %%
#verificando la lista de los inmuebles residenciales
#dfTipoPrecio.Tipo.unique()

# %%
dfTipoPrecio.index.unique()
# Out:
# Index(['Cocineta', 'Posada/Chalé', 'Casa de Vecindad', 'Estudio', 'Loft',
#        'Departamento en Hotel', 'Departamento', 'Casa', 'Rancho',
#        'Casa de Condominio'],
#       dtype='object', name='Tipo')

# %%
dfTipoPrecio.index.value_counts()
# Out:
# Tipo
# Cocineta                 1
# Posada/Chalé             1
# Casa de Vecindad         1
# Estudio                  1
# Loft                     1
# Departamento en Hotel    1
# Departamento             1
# Casa                     1
# Rancho                   1
# Casa de Condominio       1
# Name: count, dtype: int64

# %% [markdown]
# #EJERCICIO DE CONSULTA A CONTINUACION

# %%
import pandas as pd

data_ventas_region = {'Region': ['Norte', 'Sur', 'Norte', 'Sur', 'Este'],
        'Producto': ['A', 'B', 'A', 'C', 'B'],
        'Ventas': [100, 200, 150, 250, 120]}

# %%
data_ventas_region
# Out:
# {'Region': ['Norte', 'Sur', 'Norte', 'Sur', 'Este'],
#  'Producto': ['A', 'B', 'A', 'C', 'B'],
#  'Ventas': [100, 200, 150, 250, 120]}

# %%
df_ventas_region  = pd.DataFrame(data_ventas_region)

# %%
df_ventas_region
# Out:
#   Region Producto  Ventas
# 0  Norte        A     100
# 1    Sur        B     200
# 2  Norte        A     150
# 3    Sur        C     250
# 4   Este        B     120

# %%
print(df_ventas_region)
# Out:
#   Region Producto  Ventas
# 0  Norte        A     100
# 1    Sur        B     200
# 2  Norte        A     150
# 3    Sur        C     250
# 4   Este        B     120

# %%
df_ventas_region.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Region    5 non-null      object
#  1   Producto  5 non-null      object
#  2   Ventas    5 non-null      int64
# dtypes: int64(1), object(2)
# memory usage: 252.0+ bytes

# %%
ventas_por_region = df_ventas_region.groupby('Region')['Ventas'].sum()

# %%
ventas_por_region.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 3 entries, Este to Sur
# Series name: Ventas
# Non-Null Count  Dtype
# --------------  -----
# 3 non-null      int64
# dtypes: int64(1)
# memory usage: 48.0+ bytes

# %%
ventas_por_region
# Out:
# Region
# Este     120
# Norte    250
# Sur      450
# Name: Ventas, dtype: int64

# %%
print(ventas_por_region)
# Out:
# Region
# Este     120
# Norte    250
# Sur      450
# Name: Ventas, dtype: int64

# %%
#ventas_por_region.Region.unique()

# %%
ventas_por_region = pd.DataFrame(ventas_por_region)

# %%
ventas_por_region
# Out:
#         Ventas
# Region
# Este       120
# Norte      250
# Sur        450

# %%
ventas_por_region.shape
# Out:
# (3, 1)

# %%
ventas_por_region.columns
# Out:
# Index(['Ventas'], dtype='object')

# %%
df_ventas_region.shape
# Out:
# (5, 3)

# %%
df_ventas_region.columns
# Out:
# Index(['Region', 'Producto', 'Ventas'], dtype='object')

# %%
df_ventas_region.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Region    5 non-null      object
#  1   Producto  5 non-null      object
#  2   Ventas    5 non-null      int64
# dtypes: int64(1), object(2)
# memory usage: 252.0+ bytes

# %%
df_ventas_region[['Region','Ventas']]
# Out:
#   Region  Ventas
# 0  Norte     100
# 1    Sur     200
# 2  Norte     150
# 3    Sur     250
# 4   Este     120

# %% [markdown]
# #FIN DE EJERCICIO

# %% [markdown]
# #CONTINUA CAPITULO 2 SECCION 6

# %%
df_inm_residenciales.shape
# Out:
# (17309, 9)

# %%
df_inm_residenciales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17309 entries, 0 to 25119
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          17309 non-null  object
#  1   Colonia       17309 non-null  object
#  2   Habitaciones  17309 non-null  int64
#  3   Garages       17309 non-null  int64
#  4   Suites        17309 non-null  int64
#  5   Area          17309 non-null  int64
#  6   Valor         17302 non-null  float64
#  7   Condominio    16154 non-null  float64
#  8   Impuesto      12664 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 1.3+ MB

# %%
df_inm_residenciales.columns
# Out:
# Index(['Tipo', 'Colonia', 'Habitaciones', 'Garages', 'Suites', 'Area', 'Valor',
#        'Condominio', 'Impuesto'],
#       dtype='object')

# %%
#Analisando el data frame filtrado con query para solo residencial
df_inm_residenciales.Tipo.unique()
# Out:
# array(['Cocineta', 'Casa', 'Departamento', 'Casa de Condominio',
#        'Departamento en Hotel', 'Casa de Vecindad', 'Loft', 'Rancho',
#        'Posada/Chalé', 'Estudio'], dtype=object)

# %%
#analisando el value count para saber cuantos existe de cada ripo de inmueble
df_inm_residenciales.Tipo.value_counts()
# Out:
# Tipo
# Departamento             14764
# Cocineta                   726
# Casa de Condominio         610
# Casa                       545
# Departamento en Hotel      455
# Casa de Vecindad           158
# Loft                        38
# Rancho                       8
# Estudio                      4
# Posada/Chalé                 1
# Name: count, dtype: int64

# %%
#mejorar para normalizar y ver porcentajes
df_inm_residenciales.Tipo.value_counts(normalize=True)
# Out:
# Tipo
# Departamento             0.852967
# Cocineta                 0.041943
# Casa de Condominio       0.035242
# Casa                     0.031487
# Departamento en Hotel    0.026287
# Casa de Vecindad         0.009128
# Loft                     0.002195
# Rancho                   0.000462
# Estudio                  0.000231
# Posada/Chalé             0.000058
# Name: proportion, dtype: float64

# %%
#graficarlos extrayendo tipo y porcentaje
porcentaje_df_Tipo = df_inm_residenciales.Tipo.value_counts(normalize=True).to_frame()
porcentaje_df_Tipo.plot(kind='bar', figsize=(12,8), color='green', xlabel='Tipo de inmueble', ylabel='Porcentaje')
# Out:
# <Axes: xlabel='Tipo de inmueble', ylabel='Porcentaje'>

# %%
df_inm_residenciales.query('Tipo == "Departamento"')
# Out:
#                Tipo               Colonia  Habitaciones  Garages  Suites  \
# 3      Departamento      Centro Histórico             1        0       0
# 4      Departamento             Del Valle             1        0       0
# 7      Departamento      Centro Histórico             1        0       0
# 8      Departamento               Condesa             1        0       1
# 10     Departamento               Condesa             4        3       1
# ...             ...                   ...           ...      ...     ...
# 25111  Departamento  Lomas de Chapultepec             3        0       1
# 25113  Departamento              Coyoacán             3        1       2
# 25114  Departamento              Narvarte             1        0       0
# 25118  Departamento               Mixcoac             2        1       0
# 25119  Departamento  Lomas de Chapultepec             2        0       0
#
#        Area    Valor  Condominio  Impuesto
# 3        15   2800.0      1365.0      70.0
# ...

# %%
df_inm_departamento = df_inm_residenciales.query('Tipo == "Departamento"')
df_inm_departamento.head(5)
# Out:
#             Tipo           Colonia  Habitaciones  Garages  Suites  Area  \
# 3   Departamento  Centro Histórico             1        0       0    15
# 4   Departamento         Del Valle             1        0       0    48
# 7   Departamento  Centro Histórico             1        0       0    36
# 8   Departamento           Condesa             1        0       1    40
# 10  Departamento           Condesa             4        3       1   243
#
#       Valor  Condominio  Impuesto
# 3    2800.0      1365.0      70.0
# 4    2800.0       805.0       NaN
# 7    4200.0         NaN       NaN
# 8    7000.0      1963.5     175.0
# 10  45500.0      7000.0    2810.5

# %%
df_inm_departamento.shape
# Out:
# (14764, 9)

# %%
df_inm_departamento.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14764 entries, 3 to 25119
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          14764 non-null  object
#  1   Colonia       14764 non-null  object
#  2   Habitaciones  14764 non-null  int64
#  3   Garages       14764 non-null  int64
#  4   Suites        14764 non-null  int64
#  5   Area          14764 non-null  int64
#  6   Valor         14757 non-null  float64
#  7   Condominio    14271 non-null  float64
#  8   Impuesto      10967 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 1.1+ MB

# %%
type(df_inm_departamento)
# Out:
# pandas.core.frame.DataFrame

# %%
df_inm_departamento.columns
# Out:
# Index(['Tipo', 'Colonia', 'Habitaciones', 'Garages', 'Suites', 'Area', 'Valor',
#        'Condominio', 'Impuesto'],
#       dtype='object')

# %% [markdown]
# #COMPLEMENTO TEORICO

# %%
#otra forma de sacar los porcentajes
df_inm_residenciales['Tipo'].value_counts(normalize=True).to_frame().sort_values('Tipo')
# Out:
#                        proportion
# Tipo
# Casa                     0.031487
# Casa de Condominio       0.035242
# Casa de Vecindad         0.009128
# Cocineta                 0.041943
# Departamento             0.852967
# Departamento en Hotel    0.026287
# Estudio                  0.000231
# Loft                     0.002195
# Posada/Chalé             0.000058
# Rancho                   0.000462

# %%
#otra forma de sacar los porcentajes
df_inm_residenciales['Tipo'].value_counts(normalize=True).to_frame()
# Out:
#                        proportion
# Tipo
# Departamento             0.852967
# Cocineta                 0.041943
# Casa de Condominio       0.035242
# Casa                     0.031487
# Departamento en Hotel    0.026287
# Casa de Vecindad         0.009128
# Loft                     0.002195
# Rancho                   0.000462
# Estudio                  0.000231
# Posada/Chalé             0.000058

# %%
# Guardando el DataFrame en una variable
df_ejemplo = df_inm_residenciales['Tipo'].value_counts(normalize=True).to_frame().sort_values('Tipo')

df_ejemplo
# Out:
#                        proportion
# Tipo
# Casa                     0.031487
# Casa de Condominio       0.035242
# Casa de Vecindad         0.009128
# Cocineta                 0.041943
# Departamento             0.852967
# Departamento en Hotel    0.026287
# Estudio                  0.000231
# Loft                     0.002195
# Posada/Chalé             0.000058
# Rancho                   0.000462

# %%
df_ejemplo.columns
# Out:
# Index(['proportion'], dtype='object')

# %%
# Cambiando el nombre de la columna "Tipo" a "Porcentajes"
df_ejemplo.rename(columns={'Tipo': 'Porcentajes'}, inplace=True)

df_ejemplo
# Out:
#                        proportion
# Tipo
# Casa                     0.031487
# Casa de Condominio       0.035242
# Casa de Vecindad         0.009128
# Cocineta                 0.041943
# Departamento             0.852967
# Departamento en Hotel    0.026287
# Estudio                  0.000231
# Loft                     0.002195
# Posada/Chalé             0.000058
# Rancho                   0.000462

# %%
# Visualizando el DataFrame
df_ejemplo
# Out:
#                        proportion
# Tipo
# Casa                     0.031487
# Casa de Condominio       0.035242
# Casa de Vecindad         0.009128
# Cocineta                 0.041943
# Departamento             0.852967
# Departamento en Hotel    0.026287
# Estudio                  0.000231
# Loft                     0.002195
# Posada/Chalé             0.000058
# Rancho                   0.000462

# %%
# Guardando el DataFrame en una variable
df_ejemplo = df_inm_residenciales['Tipo'].value_counts(normalize=True).to_frame()

# Cambiando el nombre de la columna "Tipo" a "Porcentajes"
df_ejemplo.rename(columns={'Tipo': 'Porcentajes'}, inplace=True)

# Visualizando el DataFrame
df_ejemplo
# Out:
#                        proportion
# Tipo
# Departamento             0.852967
# Cocineta                 0.041943
# Casa de Condominio       0.035242
# Casa                     0.031487
# Departamento en Hotel    0.026287
# Casa de Vecindad         0.009128
# Loft                     0.002195
# Rancho                   0.000462
# Estudio                  0.000231
# Posada/Chalé             0.000058

# %% [markdown]
# # fin de ejercicio complementarior

# %% [markdown]
# #EJERCICIO CAPITULO 3 SECCION 9 DESAFIO

# %%
df_inm_residenciales
# Out:
#                      Tipo               Colonia  Habitaciones  Garages  \
# 0                Cocineta               Condesa             1        0
# 1                    Casa               Polanco             2        0
# 3            Departamento      Centro Histórico             1        0
# 4            Departamento             Del Valle             1        0
# 5      Casa de Condominio              Santa Fe             5        4
# ...                   ...                   ...           ...      ...
# 25114        Departamento              Narvarte             1        0
# 25115  Casa de Condominio              Santa Fe             5        3
# 25117            Cocineta      Centro Histórico             0        0
# 25118        Departamento               Mixcoac             2        1
# 25119        Departamento  Lomas de Chapultepec             2        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# 0           0    40   5950.0      1750.0     210.0
# ...

# %%
# calcular el promedio de habitaciones
df_inm_residenciales['Habitaciones'].mean()
# Out:
# np.float64(2.4906118204402334)

# %%
#cuántos barrios únicos existen en la base de datos
len(df_inm_residenciales['Colonia'].unique())
# Out:
# 87

# %%
#r un método de Pandas que realiza directamente el conteo de elementos únicos en una columna específica
df_inm_residenciales['Colonia'].nunique()
# Out:
# 87

# %%
#Para analizar qué barrios tienen el promedio de valor de alquiler más alto
df_inm_residenciales.groupby('Colonia')[['Valor']].mean().sort_values('Valor', ascending=False)
# Out:
#                                   Valor
# Colonia
# Los Alpes                  58707.173913
# Xochimilco                 36925.000000
# Bosques de Aragón          32621.289474
# Coyoacán                   32186.409021
# Lomas de Chapultepec       30081.735272
# ...                                 ...
# Santa Marta Acatitla        2302.391304
# Las Aguilas                 2100.000000
# Santa María Aztahuacán      2030.000000
# San Mateo                   1750.000000
# Potrero de San Bernardino   1190.000000
#
# [87 rows x 1 columns]

# %%
#crear un gráfico con solo las 5 colonias que tienen el promedio de alquiler más alto, podemos usar .head() para seleccionar las 5 primeras
df_colonias = df_inm_residenciales.groupby('Colonia')[['Valor']].mean().sort_values('Valor', ascending=False).head()

# %%
df_colonias
# Out:
#                              Valor
# Colonia
# Los Alpes             58707.173913
# Xochimilco            36925.000000
# Bosques de Aragón     32621.289474
# Coyoacán              32186.409021
# Lomas de Chapultepec  30081.735272

# %%
#PLOTEANDO
df_colonias.plot(kind='barh', figsize=(14,10), color='blue');

# %% [markdown]
# # FINAL DEL DESAFIO

# %% [markdown]
# #INICIO DE CAPITULO 4

# %%
#TAMAÑO DE FILAS Y COLUMNAS DEL FRAME
df_inm_departamento.shape
# Out:
# (14764, 9)

# %% [markdown]
# ###**Tratamiento de datos nulos**

# %%
#IDENTIFICACION DE COLUMNAS
df_inm_departamento.columns
# Out:
# Index(['Tipo', 'Colonia', 'Habitaciones', 'Garages', 'Suites', 'Area', 'Valor',
#        'Condominio', 'Impuesto'],
#       dtype='object')

# %%
#IDENTIFICAR NULOS
df_inm_departamento.isnull()
# Out:
#         Tipo  Colonia  Habitaciones  Garages  Suites   Area  Valor  \
# 3      False    False         False    False   False  False  False
# 4      False    False         False    False   False  False  False
# 7      False    False         False    False   False  False  False
# 8      False    False         False    False   False  False  False
# 10     False    False         False    False   False  False  False
# ...      ...      ...           ...      ...     ...    ...    ...
# 25111  False    False         False    False   False  False  False
# 25113  False    False         False    False   False  False  False
# 25114  False    False         False    False   False  False  False
# 25118  False    False         False    False   False  False  False
# 25119  False    False         False    False   False  False  False
#
#        Condominio  Impuesto
# 3           False     False
# 4           False      True
# 7            True      True
# 8           False     False
# ...

# %%
#revisar la cantidad de nulos
df_inm_departamento.isnull().sum()
# Out:
# Tipo               0
# Colonia            0
# Habitaciones       0
# Garages            0
# Suites             0
# Area               0
# Valor              7
# Condominio       493
# Impuesto        3797
# dtype: int64

# %%
# en este caso el area de ML indicaron q requerian nulos asignarles 0 PERO NO ES LO NORMAL
df_inm_departamento.fillna(0)
# Out:
#                Tipo               Colonia  Habitaciones  Garages  Suites  \
# 3      Departamento      Centro Histórico             1        0       0
# 4      Departamento             Del Valle             1        0       0
# 7      Departamento      Centro Histórico             1        0       0
# 8      Departamento               Condesa             1        0       1
# 10     Departamento               Condesa             4        3       1
# ...             ...                   ...           ...      ...     ...
# 25111  Departamento  Lomas de Chapultepec             3        0       1
# 25113  Departamento              Coyoacán             3        1       2
# 25114  Departamento              Narvarte             1        0       0
# 25118  Departamento               Mixcoac             2        1       0
# 25119  Departamento  Lomas de Chapultepec             2        0       0
#
#        Area    Valor  Condominio  Impuesto
# 3        15   2800.0      1365.0      70.0
# ...

# %%
# ahora si se guarda en la misma variable df_inm_departamento
df_inm_departamento = df_inm_departamento.fillna(0)

# %%
df_inm_departamento
# Out:
#                Tipo               Colonia  Habitaciones  Garages  Suites  \
# 3      Departamento      Centro Histórico             1        0       0
# 4      Departamento             Del Valle             1        0       0
# 7      Departamento      Centro Histórico             1        0       0
# 8      Departamento               Condesa             1        0       1
# 10     Departamento               Condesa             4        3       1
# ...             ...                   ...           ...      ...     ...
# 25111  Departamento  Lomas de Chapultepec             3        0       1
# 25113  Departamento              Coyoacán             3        1       2
# 25114  Departamento              Narvarte             1        0       0
# 25118  Departamento               Mixcoac             2        1       0
# 25119  Departamento  Lomas de Chapultepec             2        0       0
#
#        Area    Valor  Condominio  Impuesto
# 3        15   2800.0      1365.0      70.0
# ...

# %%
# revisando si cambiaron los nulos a cero

df_inm_departamento.isnull()
# Out:
#         Tipo  Colonia  Habitaciones  Garages  Suites   Area  Valor  \
# 3      False    False         False    False   False  False  False
# 4      False    False         False    False   False  False  False
# 7      False    False         False    False   False  False  False
# 8      False    False         False    False   False  False  False
# 10     False    False         False    False   False  False  False
# ...      ...      ...           ...      ...     ...    ...    ...
# 25111  False    False         False    False   False  False  False
# 25113  False    False         False    False   False  False  False
# 25114  False    False         False    False   False  False  False
# 25118  False    False         False    False   False  False  False
# 25119  False    False         False    False   False  False  False
#
#        Condominio  Impuesto
# 3           False     False
# 4           False     False
# 7           False     False
# 8           False     False
# ...

# %%
# verificando la cantidad de nulos
df_inm_departamento.isnull().sum()
# Out:
# Tipo            0
# Colonia         0
# Habitaciones    0
# Garages         0
# Suites          0
# Area            0
# Valor           0
# Condominio      0
# Impuesto        0
# dtype: int64

# %% [markdown]
# Eliminar los datos nulos: Es posible eliminar las filas o columnas que contienen valores nulos utilizando el método dropna(). Este método elimina todas las filas o columnas que tienen al menos un valor nulo.

# %% [markdown]
# Llenar los datos nulos: Utilizando el método fillna(), podemos llenar los valores nulos con un valor específico. Además, también es posible utilizar argumentos específicos del método fillna(), como method="ffill" o method="bfill", para llenar los valores nulos con el valor anterior o posterior, respectivamente.

# %% [markdown]
# Interpolar los datos nulos: Es posible utilizar el método interpolate() para llenar los valores nulos con valores interpolados, es decir, valores calculados a partir de los valores vecinos.

# %% [markdown]
# ##**FIN Tratamiento de datos nulos**

# %% [markdown]
# ###**REMOVER REGISTROS INCONSISTENTES**

# %%
df_inm_departamento.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14764 entries, 3 to 25119
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          14764 non-null  object
#  1   Colonia       14764 non-null  object
#  2   Habitaciones  14764 non-null  int64
#  3   Garages       14764 non-null  int64
#  4   Suites        14764 non-null  int64
#  5   Area          14764 non-null  int64
#  6   Valor         14764 non-null  float64
#  7   Condominio    14764 non-null  float64
#  8   Impuesto      14764 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 1.1+ MB

# %%
df_inm_departamento.shape
# Out:
# (14764, 9)

# %%
df_inm_departamento.columns
# Out:
# Index(['Tipo', 'Colonia', 'Habitaciones', 'Garages', 'Suites', 'Area', 'Valor',
#        'Condominio', 'Impuesto'],
#       dtype='object')

# %%
df_inm_departamento
# Out:
#                Tipo               Colonia  Habitaciones  Garages  Suites  \
# 3      Departamento      Centro Histórico             1        0       0
# 4      Departamento             Del Valle             1        0       0
# 7      Departamento      Centro Histórico             1        0       0
# 8      Departamento               Condesa             1        0       1
# 10     Departamento               Condesa             4        3       1
# ...             ...                   ...           ...      ...     ...
# 25111  Departamento  Lomas de Chapultepec             3        0       1
# 25113  Departamento              Coyoacán             3        1       2
# 25114  Departamento              Narvarte             1        0       0
# 25118  Departamento               Mixcoac             2        1       0
# 25119  Departamento  Lomas de Chapultepec             2        0       0
#
#        Area    Valor  Condominio  Impuesto
# 3        15   2800.0      1365.0      70.0
# ...

# %%
# esta funcion no funcionó df_inm_departamento.query('Valor == 0 ¦ Condominio == 0') df_inm_departamento.query('Valor == 0 │ Condominio == 0')

df_inm_departamento.query('Valor == 0 or Condominio == 0')
# Out:
#                Tipo                 Colonia  Habitaciones  Garages  Suites  \
# 7      Departamento        Centro Histórico             1        0       0
# 49     Departamento                Santa Fe             2        1       1
# 74     Departamento  Ciudad de los Deportes             2        0       0
# 116    Departamento              El Rosedal             2        1       0
# 136    Departamento                Santa Fe             1        1       1
# ...             ...                     ...           ...      ...     ...
# 24721  Departamento                Doctores             2        0       0
# 24736  Departamento                 Condesa             1        0       0
# 24866  Departamento                 Condesa             3        0       0
# 24892  Departamento             Loma Bonita             1        0       0
# 25014  Departamento           Culhuacán CTM             3        0       1
#
#        Area    Valor  Condominio  Impuesto
# ...

# %%
df_inm_departamento.query('Valor==0 or Condominio==0').index
# Out:
# Index([    7,    49,    74,   116,   136,   185,   199,   432,   504,   527,
#        ...
#        24426, 24555, 24563, 24597, 24671, 24721, 24736, 24866, 24892, 25014],
#       dtype='int64', length=500)

# %%
df_inm_departamento_remover = df_inm_departamento.query('Valor==0 or Condominio==0').index

# %%
df_inm_departamento_remover
# Out:
# Index([    7,    49,    74,   116,   136,   185,   199,   432,   504,   527,
#        ...
#        24426, 24555, 24563, 24597, 24671, 24721, 24736, 24866, 24892, 25014],
#       dtype='int64', length=500)

# %%
df_inm_departamento.drop(df_inm_departamento_remover,axis=0,inplace=True)

# %%
df_inm_departamento.query('Valor==0 or Condominio==0').index
# Out:
# Index([], dtype='int64')

# %%
df_inm_departamento.head()
# Out:
#             Tipo           Colonia  Habitaciones  Garages  Suites  Area  \
# 3   Departamento  Centro Histórico             1        0       0    15
# 4   Departamento         Del Valle             1        0       0    48
# 8   Departamento           Condesa             1        0       1    40
# 10  Departamento           Condesa             4        3       1   243
# 13  Departamento          Santa Fe             2        1       1    67
#
#       Valor  Condominio  Impuesto
# 3    2800.0      1365.0      70.0
# 4    2800.0       805.0       0.0
# 8    7000.0      1963.5     175.0
# 10  45500.0      7000.0    2810.5
# 13   5950.0      2061.5     514.5

# %%
df_inm_departamento.drop('Tipo',axis=1,inplace=True)
df_inm_departamento.sample(10)
# Out:
#                       Colonia  Habitaciones  Garages  Suites  Area    Valor  \
# 4055                     Roma             2        1       1    90  17500.0
# 10716                 Condesa             2        0       0    75  11200.0
# 5086                 Narvarte             2        0       0    80   4550.0
# 7272                 Coyoacán             3        1       3   228  70000.0
# 22479                 Condesa             1        0       0    32   3850.0
# 4362                  Condesa             3        1       1   140  21000.0
# 18168        Centro Histórico             2        1       1   118   8750.0
# 16909                Coyoacán             3        1       1    85  12250.0
# 7172   Ciudad de los Deportes             3        1       0    61   3500.0
# 8121                  Napoles             3        1       0    97   9800.0
#
#        Condominio  Impuesto
# 4055       7350.0     735.0
# 10716      1925.0     140.0
# 5086       1155.0      87.5
# ...

# %%
df_inm_departamento
# Out:
#                     Colonia  Habitaciones  Garages  Suites  Area    Valor  \
# 3          Centro Histórico             1        0       0    15   2800.0
# 4                 Del Valle             1        0       0    48   2800.0
# 8                   Condesa             1        0       1    40   7000.0
# 10                  Condesa             4        3       1   243  45500.0
# 13                 Santa Fe             2        1       1    67   5950.0
# ...                     ...           ...      ...     ...   ...      ...
# 25111  Lomas de Chapultepec             3        0       1    80  10500.0
# 25113              Coyoacán             3        1       2   150  52500.0
# 25114              Narvarte             1        0       0    28   3500.0
# 25118               Mixcoac             2        1       0    48   4900.0
# 25119  Lomas de Chapultepec             2        0       0    70  10500.0
#
#        Condominio  Impuesto
# 3          1365.0      70.0
# ...

# %%
df_inm_departamento.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14264 entries, 3 to 25119
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Colonia       14264 non-null  object
#  1   Habitaciones  14264 non-null  int64
#  2   Garages       14264 non-null  int64
#  3   Suites        14264 non-null  int64
#  4   Area          14264 non-null  int64
#  5   Valor         14264 non-null  float64
#  6   Condominio    14264 non-null  float64
#  7   Impuesto      14264 non-null  float64
# dtypes: float64(3), int64(4), object(1)
# memory usage: 1002.9+ KB

# %% [markdown]
# #**INICIO EJERCICIO CAPITULO 4 SECCION 5 **

# %%
import pandas as pd

datos_ejercicio_c4_s5 = pd.DataFrame([['Plaza', 'Cebolla', 2.5],
                      ['Mercado', 'Cebolla', 1.99],
                      ['Supermercado', 'Cebolla', 1.69],
                      ['Plaza', 'Tomate', 4],
                      ['Mercado', 'Tomate', 3.29],
                      ['Supermercado', 'Tomate', 2.99],
                      ['Plaza', 'Papa', 4.2],
                      ['Mercado', 'Papa', 3.99],
                      ['Supermercado', 'Papa', 3.69]],
                      columns = ['Comercio', 'Producto', 'Precio'])

# %%
datos_ejercicio_c4_s5
# Out:
#        Comercio Producto  Precio
# 0         Plaza  Cebolla    2.50
# 1       Mercado  Cebolla    1.99
# 2  Supermercado  Cebolla    1.69
# 3         Plaza   Tomate    4.00
# 4       Mercado   Tomate    3.29
# 5  Supermercado   Tomate    2.99
# 6         Plaza     Papa    4.20
# 7       Mercado     Papa    3.99
# 8  Supermercado     Papa    3.69

# %%
datos_ejercicio_c4_s5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Comercio  9 non-null      object
#  1   Producto  9 non-null      object
#  2   Precio    9 non-null      float64
# dtypes: float64(1), object(2)
# memory usage: 348.0+ bytes

# %%
#datos_ejercicio_c4_s5.drop('Comercio == Supermercado', axis=0,inplace=True)

# %%
#datos_ejercicio_c4_s5.drop([2, 5, 8], axis=0, inplace=True)

#De esta manera, pasamos una lista con los índices de las filas en las que, en la columna "Comercio", tenemos "Supermercado",
#es decir, los índices de las filas que deseamos eliminar. También se especifica axis=0, lo que indica que deseamos eliminar filas.

# %%
datos_ejercicio_c4_s5
# Out:
#        Comercio Producto  Precio
# 0         Plaza  Cebolla    2.50
# 1       Mercado  Cebolla    1.99
# 2  Supermercado  Cebolla    1.69
# 3         Plaza   Tomate    4.00
# 4       Mercado   Tomate    3.29
# 5  Supermercado   Tomate    2.99
# 6         Plaza     Papa    4.20
# 7       Mercado     Papa    3.99
# 8  Supermercado     Papa    3.69

# %% [markdown]
# datos.drop([1, 4, 7], axis=0, inplace=True)
#
# Con este fragmento de código, eliminamos las filas en las que la columna "Comercio" tiene los valores "Mercado", no "Supermercado".
#
# Alternativa incorreta
# datos.drop('Comercio', axis=1, inplace=True)
#
# Utilizando este código, estamos eliminando toda la columna "Comercio" del DataFrame, no las filas con "Supermercado".
#
#
# datos.drop('Supermercado', axis=1, inplace=True)
#
# Al ejecutar este código, se generará un error. Esto se debe a que intenta eliminar una columna llamada "Supermercado" porque especificamos axis=1. Como esa columna no existe, se genera un error.

# %% [markdown]
# #FIN EJERCICIO CAPITULO 4 SECCION 5

# %% [markdown]
# #INICIO CAPITULO 4 SECCION 5

# %% [markdown]
# ## **CREANDO FILTROS**

# %% [markdown]
# ####1.Apartamentos que tienen 1 dormitorio y un alquiler menor a MXN 4200.

# %%
#Creando una serie que tiene solo unos de la columna  habirtacionaes
seleccion_1 = df_inm_departamento['Habitaciones'] == 1

# %%
type(seleccion_1)
# Out:
# pandas.core.series.Series

# %%
seleccion_1.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 14264 entries, 3 to 25119
# Series name: Habitaciones
# Non-Null Count  Dtype
# --------------  -----
# 14264 non-null  bool
# dtypes: bool(1)
# memory usage: 125.4 KB

# %%
seleccion_1
# Out:
# 3         True
# 4         True
# 8         True
# 10       False
# 13       False
#          ...
# 25111    False
# 25113    False
# 25114     True
# 25118    False
# 25119    False
# Name: Habitaciones, Length: 14264, dtype: bool

# %%
#Creando una mascar para seleccionar las habitaciones con una sola habitacion
df_inm_departamento[seleccion_1]
# Out:
#                     Colonia  Habitaciones  Garages  Suites  Area    Valor  \
# 3          Centro Histórico             1        0       0    15   2800.0
# 4                 Del Valle             1        0       0    48   2800.0
# 8                   Condesa             1        0       1    40   7000.0
# 19                 Narvarte             1        0       0    48   2625.0
# 37         Centro Histórico             1        0       0    27   2625.0
# ...                     ...           ...      ...     ...   ...      ...
# 25090              Coyoacán             1        0       0    55   7000.0
# 25092              Santa Fe             1        1       0    62   5950.0
# 25100  Lomas de Chapultepec             1        1       1    50  15050.0
# 25103               Condesa             1        0       0    50   6825.0
# 25114              Narvarte             1        0       0    28   3500.0
#
#        Condominio  Impuesto
# 3          1365.0      70.0
# ...

# %%
# seleccion para valor menor a 4200 pesos MEX
seleccion_2 = df_inm_departamento['Valor'] < 4200

# %%
# resultado de la msacara
df_inm_departamento[seleccion_2]
# Out:
#                   Colonia  Habitaciones  Garages  Suites  Area   Valor  \
# 3        Centro Histórico             1        0       0    15  2800.0
# 4               Del Valle             1        0       0    48  2800.0
# 19               Narvarte             1        0       0    48  2625.0
# 37       Centro Histórico             1        0       0    27  2625.0
# 61       Centro Histórico             1        1       0    37  3850.0
# ...                   ...           ...      ...     ...   ...     ...
# 25038  Villa de Guadalupe             2        1       0    50  2800.0
# 25051           Nativitas             2        1       0    62  3500.0
# 25065           Nativitas             2        1       0    50  3150.0
# 25095      Lindavista Sur             2        0       0    63  2800.0
# 25114            Narvarte             1        0       0    28  3500.0
#
#        Condominio  Impuesto
# 3          1365.0      70.0
# 4           805.0       0.0
# ...

# %%
# funcion para verificar valores maximos

df_inm_departamento[seleccion_2].max()
# Out:
# Colonia         Álvaro Obregón
# Habitaciones                 3
# Garages                      2
# Suites                       2
# Area                       176
# Valor                   4025.0
# Condominio            152575.5
# Impuesto                6699.0
# dtype: object

# %%
#se hace el filtro para que cumpla las dos condiciones
filtro_1 = (seleccion_1) & (seleccion_2)

# %%
# aplicando el filtro a todo el data frame
df_inm_departamento[filtro_1]
# Out:
#                 Colonia  Habitaciones  Garages  Suites  Area   Valor  \
# 3      Centro Histórico             1        0       0    15  2800.0
# 4             Del Valle             1        0       0    48  2800.0
# 19             Narvarte             1        0       0    48  2625.0
# 37     Centro Histórico             1        0       0    27  2625.0
# 61     Centro Histórico             1        1       0    37  3850.0
# ...                 ...           ...      ...     ...   ...     ...
# 24710         Nativitas             1        0       0    40  3150.0
# 24872        Peralvillo             1        0       1    69  3150.0
# 24880        La Condesa             1        0       0    46  3850.0
# 24943              Roma             1        0       0    21  3500.0
# 25114          Narvarte             1        0       0    28  3500.0
#
#        Condominio  Impuesto
# 3          1365.0      70.0
# 4           805.0       0.0
# 19         2702.0      87.5
# ...

# %%
df_inm_departamento_filtro_1 = df_inm_departamento[filtro_1]

# %%
df_inm_departamento_filtro_1
# Out:
#                 Colonia  Habitaciones  Garages  Suites  Area   Valor  \
# 3      Centro Histórico             1        0       0    15  2800.0
# 4             Del Valle             1        0       0    48  2800.0
# 19             Narvarte             1        0       0    48  2625.0
# 37     Centro Histórico             1        0       0    27  2625.0
# 61     Centro Histórico             1        1       0    37  3850.0
# ...                 ...           ...      ...     ...   ...     ...
# 24710         Nativitas             1        0       0    40  3150.0
# 24872        Peralvillo             1        0       1    69  3150.0
# 24880        La Condesa             1        0       0    46  3850.0
# 24943              Roma             1        0       0    21  3500.0
# 25114          Narvarte             1        0       0    28  3500.0
#
#        Condominio  Impuesto
# 3          1365.0      70.0
# 4           805.0       0.0
# 19         2702.0      87.5
# ...

# %% [markdown]
# ####2.Apartamentos que tienen al menos 2 dormitorios, un alquiler menor a MXN 10500 y una superficie mayor a 70 m².

# %%
# haciendo directamente sin selecciones
filtro_2 = (df_inm_departamento['Habitaciones'] >= 2) & (df_inm_departamento['Valor'] < 10500) & (df_inm_departamento['Area'] > 70)

# %%
df_inm_departamento[filtro_2]
# Out:
#          Colonia  Habitaciones  Garages  Suites  Area   Valor  Condominio  \
# 14      Narvarte             2        1       0   110  6650.0      2450.0
# 16      Narvarte             2        1       0    78  7000.0      2450.0
# 21          Roma             2        1       0    76  8750.0      2590.0
# 33      Santa Fe             3        1       1    72  8225.0      2100.0
# 58      Santa Fe             3        2       1   104  9100.0      4774.0
# ...          ...           ...      ...     ...   ...     ...         ...
# 25028  Del Valle             2        0       1    90  7700.0      1890.0
# 25062   Santa Fe             2        1       1    72  5950.0      3045.0
# 25063   Narvarte             3        1       0    75  6650.0      3010.0
# 25105   Santa Fe             2        1       1    85  7875.0      5463.5
# 25106   Santa Fe             3        2       0    98  8050.0      3104.5
#
#        Impuesto
# 14        483.0
# 16          0.0
# 21          0.0
# ...

# %%
df_inm_departamento_filtro_2 = df_inm_departamento[filtro_2]

# %%
df_inm_departamento_filtro_2
# Out:
#          Colonia  Habitaciones  Garages  Suites  Area   Valor  Condominio  \
# 14      Narvarte             2        1       0   110  6650.0      2450.0
# 16      Narvarte             2        1       0    78  7000.0      2450.0
# 21          Roma             2        1       0    76  8750.0      2590.0
# 33      Santa Fe             3        1       1    72  8225.0      2100.0
# 58      Santa Fe             3        2       1   104  9100.0      4774.0
# ...          ...           ...      ...     ...   ...     ...         ...
# 25028  Del Valle             2        0       1    90  7700.0      1890.0
# 25062   Santa Fe             2        1       1    72  5950.0      3045.0
# 25063   Narvarte             3        1       0    75  6650.0      3010.0
# 25105   Santa Fe             2        1       1    85  7875.0      5463.5
# 25106   Santa Fe             3        2       0    98  8050.0      3104.5
#
#        Impuesto
# 14        483.0
# 16          0.0
# 21          0.0
# ...

# %% [markdown]
# #INICIO EJERCICIO SEWCCION 7 CAPITULO 4

# %% [markdown]
# seleccion = (df['Area'] > 80) | (df['Valor'] < 4000)
# df[seleccion]
#
# Muy bien, de esta manera, estamos realizando el filtro exactamente como lo solicitó el equipo de Machine Learning.
#
# Alternativa incorreta
# seleccion = (df['Area'] > 4000) & (df['Valor'] < 80)
# df[seleccion]
#
# Con este filtro, estamos especificando que queremos apartamentos con un área mayor de 4000 m² y un valor de alquiler menor de MXN 80,00. Esto probablemente no nos dará ningún resultado, ya que son valores incoherentes con las respectivas columnas.
#
# Alternativa incorreta
# seleccion = (df['Area'] < 80) | (df['Valor'] > 4000)
# df[seleccion]
#
# Aplicando este filtro, obtendremos como resultado los apartamentos con un área menor de 80 m² o un valor de alquiler mayor de 4.000 pesos. Esto no cumple con lo que se solicitó.
#
# Alternativa incorreta
# seleccion = (df['Area'] > 80) & (df['Valor'] < 4000)
# df[seleccion]
#
# Utilizando este código, obtendremos los datos de los apartamentos que tienen un área mayor de 80 m² y un alquiler menor de 4.000 pesos, ya que estamos utilizando el operador "y" (and).

# %% [markdown]
# ###**GUARDANDO LOS ARCHIVOS **

# %%
df_inm_departamento
# Out:
#                     Colonia  Habitaciones  Garages  Suites  Area    Valor  \
# 3          Centro Histórico             1        0       0    15   2800.0
# 4                 Del Valle             1        0       0    48   2800.0
# 8                   Condesa             1        0       1    40   7000.0
# 10                  Condesa             4        3       1   243  45500.0
# 13                 Santa Fe             2        1       1    67   5950.0
# ...                     ...           ...      ...     ...   ...      ...
# 25111  Lomas de Chapultepec             3        0       1    80  10500.0
# 25113              Coyoacán             3        1       2   150  52500.0
# 25114              Narvarte             1        0       0    28   3500.0
# 25118               Mixcoac             2        1       0    48   4900.0
# 25119  Lomas de Chapultepec             2        0       0    70  10500.0
#
#        Condominio  Impuesto
# 3          1365.0      70.0
# ...

# %%
#Generando archivo CSV
df_inm_departamento.to_csv('inmuebles_mac_lear.csv')

# %%
#leyendo el archivo , PERO CON UNA COLUMNA UNAMED
pd.read_csv('inmuebles_mac_lear.csv')
# Out:
#        Unnamed: 0               Colonia  Habitaciones  Garages  Suites  Area  \
# 0               3      Centro Histórico             1        0       0    15
# 1               4             Del Valle             1        0       0    48
# 2               8               Condesa             1        0       1    40
# 3              10               Condesa             4        3       1   243
# 4              13              Santa Fe             2        1       1    67
# ...           ...                   ...           ...      ...     ...   ...
# 14259       25111  Lomas de Chapultepec             3        0       1    80
# 14260       25113              Coyoacán             3        1       2   150
# 14261       25114              Narvarte             1        0       0    28
# 14262       25118               Mixcoac             2        1       0    48
# 14263       25119  Lomas de Chapultepec             2        0       0    70
#
#          Valor  Condominio  Impuesto
# ...

# %%
# QUITANDO LA COLUMNA UNEMED
df_inm_departamento.to_csv('inmuebles_mac_lear.csv',index=False)

# %%
#leyendo el archivo , PERO CON UNA COLUMNA UNAMED
pd.read_csv('inmuebles_mac_lear.csv')
# PERO EL SEPARADOR ESTA CON COMA Y DE BEBE SER CON PUNTO Y COMA
# Out:
#                     Colonia  Habitaciones  Garages  Suites  Area    Valor  \
# 0          Centro Histórico             1        0       0    15   2800.0
# 1                 Del Valle             1        0       0    48   2800.0
# 2                   Condesa             1        0       1    40   7000.0
# 3                   Condesa             4        3       1   243  45500.0
# 4                  Santa Fe             2        1       1    67   5950.0
# ...                     ...           ...      ...     ...   ...      ...
# 14259  Lomas de Chapultepec             3        0       1    80  10500.0
# 14260              Coyoacán             3        1       2   150  52500.0
# 14261              Narvarte             1        0       0    28   3500.0
# 14262               Mixcoac             2        1       0    48   4900.0
# 14263  Lomas de Chapultepec             2        0       0    70  10500.0
#
#        Condominio  Impuesto
# 0          1365.0      70.0
# ...

# %%
# QUITANDO LA COLUMNA UNEMED y GUARDANDO CON SEPARADOR POR PUNTO Y COMA
df_inm_departamento.to_csv('inmuebles_mac_lear.csv',index=False,sep=';')

# %%
df_inm_departamento
# Out:
#                     Colonia  Habitaciones  Garages  Suites  Area    Valor  \
# 3          Centro Histórico             1        0       0    15   2800.0
# 4                 Del Valle             1        0       0    48   2800.0
# 8                   Condesa             1        0       1    40   7000.0
# 10                  Condesa             4        3       1   243  45500.0
# 13                 Santa Fe             2        1       1    67   5950.0
# ...                     ...           ...      ...     ...   ...      ...
# 25111  Lomas de Chapultepec             3        0       1    80  10500.0
# 25113              Coyoacán             3        1       2   150  52500.0
# 25114              Narvarte             1        0       0    28   3500.0
# 25118               Mixcoac             2        1       0    48   4900.0
# 25119  Lomas de Chapultepec             2        0       0    70  10500.0
#
#        Condominio  Impuesto
# 3          1365.0      70.0
# ...

# %%
# GENERANDO LOS DATA FREME DE LOS FILTROS
df_inm_departamento_filtro_1.to_csv('inmuebles_mac_lear_filtro_1.csv',index=False,sep=';')
df_inm_departamento_filtro_2.to_csv('inmuebles_mac_lear_filtro_2.csv',index=False,sep=';')

# %%
df_inm_departamento_filtro_1
# Out:
#                 Colonia  Habitaciones  Garages  Suites  Area   Valor  \
# 3      Centro Histórico             1        0       0    15  2800.0
# 4             Del Valle             1        0       0    48  2800.0
# 19             Narvarte             1        0       0    48  2625.0
# 37     Centro Histórico             1        0       0    27  2625.0
# 61     Centro Histórico             1        1       0    37  3850.0
# ...                 ...           ...      ...     ...   ...     ...
# 24710         Nativitas             1        0       0    40  3150.0
# 24872        Peralvillo             1        0       1    69  3150.0
# 24880        La Condesa             1        0       0    46  3850.0
# 24943              Roma             1        0       0    21  3500.0
# 25114          Narvarte             1        0       0    28  3500.0
#
#        Condominio  Impuesto
# 3          1365.0      70.0
# 4           805.0       0.0
# 19         2702.0      87.5
# ...

# %%
df_inm_departamento_filtro_1
# Out:
#                 Colonia  Habitaciones  Garages  Suites  Area   Valor  \
# 3      Centro Histórico             1        0       0    15  2800.0
# 4             Del Valle             1        0       0    48  2800.0
# 19             Narvarte             1        0       0    48  2625.0
# 37     Centro Histórico             1        0       0    27  2625.0
# 61     Centro Histórico             1        1       0    37  3850.0
# ...                 ...           ...      ...     ...   ...     ...
# 24710         Nativitas             1        0       0    40  3150.0
# 24872        Peralvillo             1        0       1    69  3150.0
# 24880        La Condesa             1        0       0    46  3850.0
# 24943              Roma             1        0       0    21  3500.0
# 25114          Narvarte             1        0       0    28  3500.0
#
#        Condominio  Impuesto
# 3          1365.0      70.0
# 4           805.0       0.0
# 19         2702.0      87.5
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#GUARDANDO UNA COPIA DE LOS ARCHIVOS CSV EN PANDAS
df_inm_departamento.to_csv('/content/drive/MyDrive/pandas/inmuebles_mac_lear.csv',index=False,sep=';')

# %%
df_inm_departamento_filtro_1.to_csv('/content/drive/MyDrive/pandas/inmuebles_mac_lear_filtro_1.csv',index=False,sep=';')

# %%
df_inm_departamento_filtro_2.to_csv('/content/drive/MyDrive/pandas/inmuebles_mac_lear_filtro_2.csv',index=False,sep=';')

# %% [markdown]
# Para guardar estos DataFrames en formato CSV, podemos utilizar el método to_csv que ya conocemos:
#
# df_1.to_csv('filtro_1.csv', index=False, sep=";")
# df_2.to_csv('filtro_2.csv', index=False, sep=";")
# Copia el código
# Con los archivos guardados, también puede ser interesante leer cada uno de ellos utilizando read_csv() para asegurarse de que todo se haya realizado correctamente.

# %% [markdown]
#  10 Para saber más: exportando diferentes formatos
#  Siguiente pregunta
#
# Pandas proporciona varios métodos para guardar archivos en diferentes formatos. Algunos ejemplos son:
#
# to_csv(): Guarda el DataFrame en un archivo CSV (Valores Separados por Comas).
#
# to_excel(): Guarda el DataFrame en un archivo de Excel.
#
# to_json(): Guarda el DataFrame en un archivo JSON (Notación de Objetos JavaScript).
#
# Estos son solo algunos ejemplos, existen otros métodos disponibles en Pandas para guardar archivos en diferentes formatos. Si deseas conocerlos, consulta la documentación:
#
# User Guide - IO Tools
#
# https://pandas.pydata.org/docs/user_guide/io.html#io-tools-text-csv-hdf5

# %% [markdown]
# #**DESAFIO CAPITULO 4 SECCION 11**

# %% [markdown]
# 11 Desafío: vamos a practicar
#  Siguiente pregunta
#
# Para practicar los métodos aprendidos a lo largo de esta lección y aprender nuevos, realizaremos algunos tratamientos y selecciones utilizando un archivo CSV diferente: alumnos.csv.
#
# Este archivo es el mismo que se utilizó para resolver los desafíos de la lección 1 y contiene datos de estudiantes de un curso superior.
#
# Basándonos en esto, resolvamos los problemas propuestos a continuación utilizando los conocimientos adquiridos hasta ahora.
#
# Verifica si la base de datos contiene datos nulos y, en caso de tenerlos, realiza el tratamiento de estos datos nulos de la manera que consideres más coherente con la situación.
#
# Los estudiantes "Alicia" y "Carlos" ya no forman parte del grupo. Por lo tanto, elimínalos de la base de datos.
#
# Aplica un filtro que seleccione solo a los estudiantes que fueron aprobados.
#
# Guarda el DataFrame que contiene solo a los estudiantes aprobados en un archivo CSV llamado "alumnos_aprobados.csv".
#
# Extra: Al revisar las calificaciones de los estudiantes aprobados, notamos que algunas calificaciones eran incorrectas. Las estudiantes que obtuvieron una calificación de 7.0, en realidad tenían un punto extra que no se contabilizó. Por lo tanto, reemplaza las calificaciones de 7.0 en la base de datos por 8.0. Consejo: busca el método replace.
#
# Si necesitas ayuda, en la sección "Opinión del Instructor" puedes encontrar algunas formas de resolver los desafíos propuestos anteriormente.

# %%
datos_ejerc_alumnos.info
# Out:
# <bound method DataFrame.info of       Nombre  Edad  Nota   Aprobado
# 0    Alberto    20   7.5       True
# 1        Ana    18   NaN      False
# 2     Camila    27   2.5      False
# 3      David    18   5.0      False
# 4      Brian    21  10.0       True
# 5      Bruna    23   NaN      False
# 6    Daniela    21   7.0       True
# 7     Carlos    19   6.0      False
# 8     Alicia    35   5.6      False
# 9     Victor    28   NaN      False
# 10    Danilo    21   NaN      False
# 11   Ignacio    24   4.5      False
# 12  Stephany    26  10.0       True
# 13    Miriam    25   9.0       True
# 14     Pablo    37   NaN      False
# 15    Milena    29   7.0       True
# 16     Lucas    33   NaN      False
# 17     Nadia    34   8.0  Verdadero>

# %%
datos_ejerc_alumnos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Nombre    18 non-null     object
#  1   Edad      18 non-null     int64
#  2   Nota      12 non-null     float64
#  3   Aprobado  18 non-null     object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 708.0+ bytes

# %%
datos_ejerc_alumnos.columns
# Out:
# Index(['Nombre', 'Edad', 'Nota', 'Aprobado'], dtype='object')

# %%
datos_ejerc_alumnos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Nombre    18 non-null     object
#  1   Edad      18 non-null     int64
#  2   Nota      12 non-null     float64
#  3   Aprobado  18 non-null     object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 708.0+ bytes

# %%
datos_ejerc_alumnos
# Out:
#       Nombre  Edad  Nota   Aprobado
# 0    Alberto    20   7.5       True
# 1        Ana    18   NaN      False
# 2     Camila    27   2.5      False
# 3      David    18   5.0      False
# 4      Brian    21  10.0       True
# 5      Bruna    23   NaN      False
# 6    Daniela    21   7.0       True
# 7     Carlos    19   6.0      False
# 8     Alicia    35   5.6      False
# 9     Victor    28   NaN      False
# 10    Danilo    21   NaN      False
# 11   Ignacio    24   4.5      False
# 12  Stephany    26  10.0       True
# 13    Miriam    25   9.0       True
# 14     Pablo    37   NaN      False
# 15    Milena    29   7.0       True
# 16     Lucas    33   NaN      False
# 17     Nadia    34   8.0  Verdadero

# %%
#verificando datos nulos
datos_ejerc_alumnos.isnull()
# Out:
#     Nombre   Edad   Nota  Aprobado
# 0    False  False  False     False
# 1    False  False   True     False
# 2    False  False  False     False
# 3    False  False  False     False
# 4    False  False  False     False
# 5    False  False   True     False
# 6    False  False  False     False
# 7    False  False  False     False
# 8    False  False  False     False
# 9    False  False   True     False
# 10   False  False   True     False
# 11   False  False  False     False
# 12   False  False  False     False
# 13   False  False  False     False
# 14   False  False   True     False
# 15   False  False  False     False
# 16   False  False   True     False
# 17   False  False  False     False

# %%
#VARIFICANDO DATOS NULOS CANTIDADES O SUMA
datos_ejerc_alumnos.isnull().sum()
# Out:
# Nombre      0
# Edad        0
# Nota        6
# Aprobado    0
# dtype: int64

# %%
datos_ejerc_alumnos
# Out:
#       Nombre  Edad  Nota   Aprobado
# 0    Alberto    20   7.5       True
# 1        Ana    18   NaN      False
# 2     Camila    27   2.5      False
# 3      David    18   5.0      False
# 4      Brian    21  10.0       True
# 5      Bruna    23   NaN      False
# 6    Daniela    21   7.0       True
# 7     Carlos    19   6.0      False
# 8     Alicia    35   5.6      False
# 9     Victor    28   NaN      False
# 10    Danilo    21   NaN      False
# 11   Ignacio    24   4.5      False
# 12  Stephany    26  10.0       True
# 13    Miriam    25   9.0       True
# 14     Pablo    37   NaN      False
# 15    Milena    29   7.0       True
# 16     Lucas    33   NaN      False
# 17     Nadia    34   8.0  Verdadero

# %%
#VARIFICANDO DATOS NULOS CANTIDADES O SUMA
datos_ejerc_alumnos.isnull().sum()
# Out:
# Nombre      0
# Edad        0
# Nota        6
# Aprobado    0
# dtype: int64

# %%
#SOLO NOTA TIEN NULOS
# SE DECIDE REEMPLAZAR LOS NULO POR 0
datos_ejerc_alumnos.fillna(0)
# Out:
#       Nombre  Edad  Nota   Aprobado
# 0    Alberto    20   7.5       True
# 1        Ana    18   0.0      False
# 2     Camila    27   2.5      False
# 3      David    18   5.0      False
# 4      Brian    21  10.0       True
# 5      Bruna    23   0.0      False
# 6    Daniela    21   7.0       True
# 7     Carlos    19   6.0      False
# 8     Alicia    35   5.6      False
# 9     Victor    28   0.0      False
# 10    Danilo    21   0.0      False
# 11   Ignacio    24   4.5      False
# 12  Stephany    26  10.0       True
# 13    Miriam    25   9.0       True
# 14     Pablo    37   0.0      False
# 15    Milena    29   7.0       True
# 16     Lucas    33   0.0      False
# 17     Nadia    34   8.0  Verdadero

# %%
#QUITANDO LOS NULLOS EN EL MISMO DATA FRAME
datos_ejerc_alumnos = datos_ejerc_alumnos.fillna(0)

# %%
#VARIFICANDO DATOS NULOS CANTIDADES O SUMA
datos_ejerc_alumnos.isnull().sum()
# Out:
# Nombre      0
# Edad        0
# Nota        0
# Aprobado    0
# dtype: int64

# %%
# Guardamos los índices de las filas a eliminar en una variable
Alumnos_Eliminar = datos_ejerc_alumnos.query('Nombre == "Alicia" | Nombre == "Carlos"').index

# %%
type(Alumnos_Eliminar)
# Out:
# pandas.core.indexes.base.Index

# %%
Alumnos_Eliminar
# Out:
# Index([7, 8], dtype='int64')

# %%
type(Alumnos_Eliminar)
# Out:
# pandas.core.indexes.base.Index

# %%
# Eliminamos las filas correspondientes a los estudiantes "Alicia" y "Carlos"
datos_ejerc_alumnos.drop(Alumnos_Eliminar, axis=0, inplace=True)

# %%
datos_ejerc_alumnos
# Out:
#       Nombre  Edad  Nota   Aprobado
# 0    Alberto    20   7.5       True
# 1        Ana    18   0.0      False
# 2     Camila    27   2.5      False
# 3      David    18   5.0      False
# 4      Brian    21  10.0       True
# 5      Bruna    23   0.0      False
# 6    Daniela    21   7.0       True
# 9     Victor    28   0.0      False
# 10    Danilo    21   0.0      False
# 11   Ignacio    24   4.5      False
# 12  Stephany    26  10.0       True
# 13    Miriam    25   9.0       True
# 14     Pablo    37   0.0      False
# 15    Milena    29   7.0       True
# 16     Lucas    33   0.0      False
# 17     Nadia    34   8.0  Verdadero

# %%
datos_ejerc_alumnos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16 entries, 0 to 17
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Nombre    16 non-null     object
#  1   Edad      16 non-null     int64
#  2   Nota      16 non-null     float64
#  3   Aprobado  16 non-null     object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 640.0+ bytes

# %%
datos_ejerc_alumnos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16 entries, 0 to 17
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Nombre    16 non-null     object
#  1   Edad      16 non-null     int64
#  2   Nota      16 non-null     float64
#  3   Aprobado  16 non-null     object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 640.0+ bytes

# %%
#creando la seleccin de aprobados
#Seleccion_Est_Aprobados_1 = datos_ejerc_alumnos.query('Aprobado==True or '  )
Seleccion_Est_Aprobados_1 = datos_ejerc_alumnos['Aprobado'] == True
#df_inm_residenciales.query('Tipo == "Departamento" or Tipo == "Verdadero"')

# %%
Seleccion_Est_Aprobados_1
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# Name: Aprobado, dtype: bool

# %%
#creando la seleccin de aprobados
#Seleccion_Est_Aprobados_1 = datos_ejerc_alumnos.query('Aprobado==True or '  )
#Seleccion_Est_Aprobados_1 = datos_ejerc_alumnos['Aprobado'] == True
#df_inm_departamento.query('Valor == 0 or Condominio == 0')
datos_ejerc_alumnos.query('Aprobado == "True" or Aprobado == "Verdadero"')
# Out:
#       Nombre  Edad  Nota   Aprobado
# 0    Alberto    20   7.5       True
# 4      Brian    21  10.0       True
# 6    Daniela    21   7.0       True
# 12  Stephany    26  10.0       True
# 13    Miriam    25   9.0       True
# 15    Milena    29   7.0       True
# 17     Nadia    34   8.0  Verdadero

# %%
Seleccion_Est_Aprobados = datos_ejerc_alumnos.query('Aprobado == "True" or Aprobado == "Verdadero"')

# %%
Seleccion_Est_Aprobados
# Out:
#       Nombre  Edad  Nota   Aprobado
# 0    Alberto    20   7.5       True
# 4      Brian    21  10.0       True
# 6    Daniela    21   7.0       True
# 12  Stephany    26  10.0       True
# 13    Miriam    25   9.0       True
# 15    Milena    29   7.0       True
# 17     Nadia    34   8.0  Verdadero

# %%
#aplicando seleccion al data frame
#datos_ejerc_alumnos[Seleccion_Est_Aprobados]

# %%
datos_ejerc_alumnos
# Out:
#       Nombre  Edad  Nota   Aprobado
# 0    Alberto    20   7.5       True
# 1        Ana    18   0.0      False
# 2     Camila    27   2.5      False
# 3      David    18   5.0      False
# 4      Brian    21  10.0       True
# 5      Bruna    23   0.0      False
# 6    Daniela    21   7.0       True
# 9     Victor    28   0.0      False
# 10    Danilo    21   0.0      False
# 11   Ignacio    24   4.5      False
# 12  Stephany    26  10.0       True
# 13    Miriam    25   9.0       True
# 14     Pablo    37   0.0      False
# 15    Milena    29   7.0       True
# 16     Lucas    33   0.0      False
# 17     Nadia    34   8.0  Verdadero

# %%
Seleccion_Est_Aprobados
# Out:
#       Nombre  Edad  Nota   Aprobado
# 0    Alberto    20   7.5       True
# 4      Brian    21  10.0       True
# 6    Daniela    21   7.0       True
# 12  Stephany    26  10.0       True
# 13    Miriam    25   9.0       True
# 15    Milena    29   7.0       True
# 17     Nadia    34   8.0  Verdadero

# %%
#guardando en en archivo csv alumnos aprobados
Seleccion_Est_Aprobados.to_csv('Seleccion_Est_Aprobados.csv', index=False)

# %%
#Remplazar un valor
Seleccion_Est_Aprobados.replace(7.0,8.0)
# Out:
#       Nombre  Edad  Nota   Aprobado
# 0    Alberto    20   7.5       True
# 4      Brian    21  10.0       True
# 6    Daniela    21   8.0       True
# 12  Stephany    26  10.0       True
# 13    Miriam    25   9.0       True
# 15    Milena    29   8.0       True
# 17     Nadia    34   8.0  Verdadero

# %%
#seleccionando la misma variable
Seleccion_Est_Aprobados = Seleccion_Est_Aprobados.replace(7.0,8.0)

# %%
#verificando el cambio
Seleccion_Est_Aprobados
# Out:
#       Nombre  Edad  Nota   Aprobado
# 0    Alberto    20   7.5       True
# 4      Brian    21  10.0       True
# 6    Daniela    21   8.0       True
# 12  Stephany    26  10.0       True
# 13    Miriam    25   9.0       True
# 15    Milena    29   8.0       True
# 17     Nadia    34   8.0  Verdadero

# %%
#guardando en en archivo csv alumnos aprobados
Seleccion_Est_Aprobados.to_csv('Seleccion_Est_Aprobados.csv', index=False)

# %%
#GUARDANDO UNA COPIA DE LOS ARCHIVOS CSV EN PANDAS
df_inm_departamento.to_csv('/content/drive/MyDrive/pandas/Seleccion_Est_Aprobados.csv',index=False)

# %% [markdown]
# #EJERCICIO DE PRUEBA

# %%
import pandas as pd

# Crear un DataFrame de ejemplo
data_prueba_1 = {'Nombre': ['Alice', 'Bob', 'Charlie', 'David'],
        'Aprobado': [True, False, True, False]}
datos_data_prueba_1 = pd.DataFrame(data_prueba_1)

# Seleccionar las filas donde 'Aprobado' es True
seleccion = datos_data_prueba_1['Aprobado'] == True
datos_aprobados_data_prueba_1 = datos_data_prueba_1[seleccion]

print(datos_aprobados_data_prueba_1)
# Out:
#     Nombre  Aprobado
# 0    Alice      True
# 2  Charlie      True

# %%
data_prueba_1
# Out:
# {'Nombre': ['Alice', 'Bob', 'Charlie', 'David'],
#  'Aprobado': [True, False, True, False]}

# %%
datos_data_prueba_1
# Out:
#     Nombre  Aprobado
# 0    Alice      True
# 1      Bob     False
# 2  Charlie      True
# 3    David     False

# %%
datos_data_prueba_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Nombre    4 non-null      object
#  1   Aprobado  4 non-null      bool
# dtypes: bool(1), object(1)
# memory usage: 168.0+ bytes

# %% [markdown]
# #FIN EJERCICIO DE PRUEBA

# %% [markdown]
# #DEMANDAS DE DEV

# %% [markdown]
# ##**CREAR COLUMNAS NUMERICAS**

# %% [markdown]
# ### 1. valor_mensual: Esta columna debe contener los gastos mensuales de cada propiedad, incluyendo el alquiler y el condominio.

# %%
##datos_alquiler_cdmx = pd.read_csv(url_aluiler_cdmx, sep=';')
datos_alquiler_cdmx_DEV = pd.read_csv(url_aluiler_cdmx, sep=';')
datos_alquiler_cdmx_DEV
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 0                     Cocineta               Condesa             1        0
# 1                         Casa               Polanco             2        0
# 2      Conjunto Comercial/Sala              Santa Fe             0        4
# 3                 Departamento      Centro Histórico             1        0
# 4                 Departamento             Del Valle             1        0
# ...                        ...                   ...           ...      ...
# 25116  Cochera/Estacionamiento      Centro Histórico             0        0
# 25117                 Cocineta      Centro Histórico             0        0
# 25118             Departamento               Mixcoac             2        1
# 25119             Departamento  Lomas de Chapultepec             2        0
# 25120  Conjunto Comercial/Sala      Centro Histórico             0        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# ...

# %%
datos_alquiler_cdmx_DEV['Valor_Mensual'] = datos_alquiler_cdmx_DEV['Valor'] + datos_alquiler_cdmx_DEV['Condominio']
datos_alquiler_cdmx_DEV.head()
# Out:
#                       Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                 Cocineta           Condesa             1        0       0
# 1                     Casa           Polanco             2        0       1
# 2  Conjunto Comercial/Sala          Santa Fe             0        4       0
# 3             Departamento  Centro Histórico             1        0       0
# 4             Departamento         Del Valle             1        0       0
#
#    Area    Valor  Condominio  Impuesto  Valor_Mensual
# 0    40   5950.0      1750.0     210.0         7700.0
# 1   100  24500.0         NaN       NaN            NaN
# 2   150  18200.0     14070.0    3888.5        32270.0
# 3    15   2800.0      1365.0      70.0         4165.0
# 4    48   2800.0       805.0       NaN         3605.0

# %% [markdown]
# ### 2. valor_anual: Esta columna debe contener los gastos anuales por propiedad, es decir, el Impuesto más 12 meses de alquiler y condominio.

# %%
datos_alquiler_cdmx_DEV['Valor_Anual'] = (datos_alquiler_cdmx_DEV['Valor_Mensual'] * 12) + datos_alquiler_cdmx_DEV['Impuesto']
datos_alquiler_cdmx_DEV.tail()
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 25116  Cochera/Estacionamiento      Centro Histórico             0        0
# 25117                 Cocineta      Centro Histórico             0        0
# 25118             Departamento               Mixcoac             2        1
# 25119             Departamento  Lomas de Chapultepec             2        0
# 25120  Conjunto Comercial/Sala      Centro Histórico             0        0
#
#        Suites  Area    Valor  Condominio  Impuesto  Valor_Mensual  Valor_Anual
# 25116       0   755  49000.0         NaN       NaN            NaN          NaN
# 25117       0    27   2800.0      1225.0      87.5         4025.0      48387.5
# 25118       0    48   4900.0      1781.5     129.5         6681.5      80307.5
# 25119       0    70  10500.0      2660.0       NaN        13160.0          NaN
# 25120       0   250  22750.0     14721.0    3881.5        37471.0     453533.5

# %% [markdown]
# #EJERCICIO CAPITULO 4 SECCION 3

# %% [markdown]
# ##**Operaciones entre columnas**

# %%
import pandas as pd

datos_Ejer_c4_s3 = {
    'Nombre': ['Jetta', 'Passat', 'Crossfox', 'DS5', 'Escarabajo'],
    'Motor': ['Motor 4.0 Turbo', 'Motor Diesel', 'Motor Diesel V8', 'Motor 2.0', 'Motor 1.6'],
    'Modelo': [2019, 2003, 1991, 2019, 1990],
    'Kilometraje': [0.0, 5712.0, 37123.0, 0.0, 120000.0],
    'Valor': [88000.0, 106000.0, 72000.0, 89000.0, 32000.0],
    'Impuesto': [2000.0, 5000.0, 1700.0, 2200.0, 1000.0],
    'Descuento': [380.0, 450.0, 277.0, 400.0, 150.0]
}

# %%
datos_Ejer_c4_s3
# Out:
# {'Nombre': ['Jetta', 'Passat', 'Crossfox', 'DS5', 'Escarabajo'],
#  'Motor': ['Motor 4.0 Turbo',
#   'Motor Diesel',
#   'Motor Diesel V8',
#   'Motor 2.0',
#   'Motor 1.6'],
#  'Modelo': [2019, 2003, 1991, 2019, 1990],
#  'Kilometraje': [0.0, 5712.0, 37123.0, 0.0, 120000.0],
#  'Valor': [88000.0, 106000.0, 72000.0, 89000.0, 32000.0],
#  'Impuesto': [2000.0, 5000.0, 1700.0, 2200.0, 1000.0],
#  'Descuento': [380.0, 450.0, 277.0, 400.0, 150.0]}

# %%
type(datos_Ejer_c4_s3)
# Out:
# dict

# %%
df_data_Ejer_c4_s3 = pd.DataFrame(datos_Ejer_c4_s3)

# %%
df_data_Ejer_c4_s3.head()
# Out:
#        Nombre            Motor  Modelo  Kilometraje     Valor  Impuesto  \
# 0       Jetta  Motor 4.0 Turbo    2019          0.0   88000.0    2000.0
# 1      Passat     Motor Diesel    2003       5712.0  106000.0    5000.0
# 2    Crossfox  Motor Diesel V8    1991      37123.0   72000.0    1700.0
# 3         DS5        Motor 2.0    2019          0.0   89000.0    2200.0
# 4  Escarabajo        Motor 1.6    1990     120000.0   32000.0    1000.0
#
#    Descuento
# 0      380.0
# 1      450.0
# 2      277.0
# 3      400.0
# 4      150.0

# %%
type(df_data_Ejer_c4_s3)
# Out:
# pandas.core.frame.DataFrame

# %%
# Necesitamos crear una columna llamada "Valor_total" que tenga el valor del automóvil, sumado al impuesto y menos el valor del descuento.
df_data_Ejer_c4_s3['Valor_total'] = df_data_Ejer_c4_s3['Valor'] + df_data_Ejer_c4_s3['Impuesto'] - df_data_Ejer_c4_s3['Descuento']

# %%
df_data_Ejer_c4_s3.tail()
# Out:
#        Nombre            Motor  Modelo  Kilometraje     Valor  Impuesto  \
# 0       Jetta  Motor 4.0 Turbo    2019          0.0   88000.0    2000.0
# 1      Passat     Motor Diesel    2003       5712.0  106000.0    5000.0
# 2    Crossfox  Motor Diesel V8    1991      37123.0   72000.0    1700.0
# 3         DS5        Motor 2.0    2019          0.0   89000.0    2200.0
# 4  Escarabajo        Motor 1.6    1990     120000.0   32000.0    1000.0
#
#    Descuento  Valor_total
# 0      380.0      89620.0
# 1      450.0     110550.0
# 2      277.0      73423.0
# 3      400.0      90800.0
# 4      150.0      32850.0

# %% [markdown]
# #FIN DE EJERCICIO

# %% [markdown]
# #CONTINUA SECCION 4

# %% [markdown]
# ##**cREAR COLUMNAS CATEGORICAS**

# %% [markdown]
# ##**Creando la columna Descripción** texto en cursiva

# %% [markdown]
# ###1. Descripcion: Esta columna debe contener un resumen de la información clave de las propiedades que se mostrarán en el sitio web: tipo de propiedad, barrio, cantidad de habitaciones y plazas de estacionamiento.

# %%
datos_alquiler_cdmx_DEV ['Descripcion'] = datos_alquiler_cdmx_DEV ['Tipo'] + datos_alquiler_cdmx_DEV ['Colonia']

# %%
datos_alquiler_cdmx_DEV.head()
# Out:
#                       Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                 Cocineta           Condesa             1        0       0
# 1                     Casa           Polanco             2        0       1
# 2  Conjunto Comercial/Sala          Santa Fe             0        4       0
# 3             Departamento  Centro Histórico             1        0       0
# 4             Departamento         Del Valle             1        0       0
#
#    Area    Valor  Condominio  Impuesto  Valor_Mensual  Valor_Anual  \
# 0    40   5950.0      1750.0     210.0         7700.0      92610.0
# 1   100  24500.0         NaN       NaN            NaN          NaN
# 2   150  18200.0     14070.0    3888.5        32270.0     391128.5
# 3    15   2800.0      1365.0      70.0         4165.0      50050.0
# 4    48   2800.0       805.0       NaN         3605.0          NaN
#
#                        Descripcion
# 0                  CocinetaCondesa
# ...

# %%
#Los comandos completops para concatenar y mejorar la descrpcion
datos_alquiler_cdmx_DEV ['Descripcion'] = datos_alquiler_cdmx_DEV ['Tipo'] + ' en la Colonia ' + datos_alquiler_cdmx_DEV ['Colonia']

# %%
datos_alquiler_cdmx_DEV.head()
# Out:
#                       Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                 Cocineta           Condesa             1        0       0
# 1                     Casa           Polanco             2        0       1
# 2  Conjunto Comercial/Sala          Santa Fe             0        4       0
# 3             Departamento  Centro Histórico             1        0       0
# 4             Departamento         Del Valle             1        0       0
#
#    Area    Valor  Condominio  Impuesto  Valor_Mensual  Valor_Anual  \
# 0    40   5950.0      1750.0     210.0         7700.0      92610.0
# 1   100  24500.0         NaN       NaN            NaN          NaN
# 2   150  18200.0     14070.0    3888.5        32270.0     391128.5
# 3    15   2800.0      1365.0      70.0         4165.0      50050.0
# 4    48   2800.0       805.0       NaN         3605.0          NaN
#
#                                       Descripcion
# 0                  Cocineta en la Colonia Condesa
# ...

# %%
#Los comandos completops para concatenar y mejorar la descrpcion
#datos_alquiler_cdmx_DEV ['Descripcion'] = datos_alquiler_cdmx_DEV ['Tipo'] + ' en la Colonia ' + datos_alquiler_cdmx_DEV ['Colonia'] + \
   #                                         ' con ' + datos_alquiler_cdmx_DEV ['Habitaciones'] + ' cuarto(s) y ' + \
        #                                    datos_alquiler_cdmx_DEV ['Garages'] + ' Plazas de Estacionamiento.'

# %%
# correccion del erros anterior con astype para un solo tipo de dato

datos_alquiler_cdmx_DEV ['Descripcion'] = datos_alquiler_cdmx_DEV ['Tipo'] + ' en la Colonia ' + datos_alquiler_cdmx_DEV ['Colonia'] + \
                                            ' con ' + datos_alquiler_cdmx_DEV ['Habitaciones'].astype(str) + ' cuarto(s) y ' + \
                                            datos_alquiler_cdmx_DEV ['Garages'].astype(str) + ' Plazas de Estacionamiento.'

# %%
datos_alquiler_cdmx_DEV.head()
# Out:
#                       Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                 Cocineta           Condesa             1        0       0
# 1                     Casa           Polanco             2        0       1
# 2  Conjunto Comercial/Sala          Santa Fe             0        4       0
# 3             Departamento  Centro Histórico             1        0       0
# 4             Departamento         Del Valle             1        0       0
#
#    Area    Valor  Condominio  Impuesto  Valor_Mensual  Valor_Anual  \
# 0    40   5950.0      1750.0     210.0         7700.0      92610.0
# 1   100  24500.0         NaN       NaN            NaN          NaN
# 2   150  18200.0     14070.0    3888.5        32270.0     391128.5
# 3    15   2800.0      1365.0      70.0         4165.0      50050.0
# 4    48   2800.0       805.0       NaN         3605.0          NaN
#
#                                          Descripcion
# ...

# %%
#para ver una fila como queda la descripcion
datos_alquiler_cdmx_DEV.iloc[500].Descripcion
# Out:
# 'Departamento en la Colonia Napoles con 1 cuarto(s) y 0 Plazas de Estacionamiento.'

# %% [markdown]
# #CAPITULO 4 SECCION 5

# %% [markdown]
# ## 05 Para saber más: creando columnas

# %% [markdown]
# 1 - Asignación directa de valores a una nueva columna:
#
# import pandas as pd
#
# df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})
# df['C'] = [7, 8, 9]

# %% [markdown]
# 2 - Creación de una columna a partir de operaciones entre otras columnas:
#
# import pandas as pd
#
# df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})
# df['C'] = df['A'] + df['B']

# %% [markdown]
# 3 - Uso del método assign() para crear una nueva columna:
#
# import pandas as pd
#
# df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})
# df = df.assign(C=[7, 8, 9])

# %% [markdown]
# 4 - Uso del método apply() para aplicar una función a una columna existente y crear una nueva columna:
#
# import pandas as pd
#
# df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})
# df['C'] = df['A'].apply(lambda x: x * 2)

# %% [markdown]
# Si deseas profundizar en este tema, consulta la documentación:
#
# How to create new columns derived from existing columns
#
# https://pandas.pydata.org/docs/getting_started/intro_tutorials/05_add_columns.html#how-to-create-new-columns-derived-from-existing-columns

# %% [markdown]
# ###2. Tiene_suite: Esta debe ser una columna que indique únicamente si la propiedad tiene o no suites, sin importar la cantidad.

# %%
# CREANDO LA COLUIMNA SIUTE CON UNA FUNCION INTEGRADA LAMNDA PARA SI O NO EXISTE SUITE

datos_alquiler_cdmx_DEV['Tiene_suite'] = datos_alquiler_cdmx_DEV['Suites'].apply(lambda x: 'Si' if x > 0 else 'No')

# %%
datos_alquiler_cdmx_DEV.head()
# Out:
#                       Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                 Cocineta           Condesa             1        0       0
# 1                     Casa           Polanco             2        0       1
# 2  Conjunto Comercial/Sala          Santa Fe             0        4       0
# 3             Departamento  Centro Histórico             1        0       0
# 4             Departamento         Del Valle             1        0       0
#
#    Area    Valor  Condominio  Impuesto  Valor_Mensual  Valor_Anual  \
# 0    40   5950.0      1750.0     210.0         7700.0      92610.0
# 1   100  24500.0         NaN       NaN            NaN          NaN
# 2   150  18200.0     14070.0    3888.5        32270.0     391128.5
# 3    15   2800.0      1365.0      70.0         4165.0      50050.0
# 4    48   2800.0       805.0       NaN         3605.0          NaN
#
#                                          Descripcion Tiene_suite
# ...

# %%
# guardando la copia en el drive sin el index y separador de punto y coma

datos_alquiler_cdmx_DEV.to_csv('/content/drive/MyDrive/pandas/inmuebes_alquiler_cdmx_DEV.csv', index=False, sep=';')

# %% [markdown]
# # CAPITULO CUATRO SECCION 7

# %% [markdown]
# ##** Desafío: vamos a practicar**

# %% [markdown]
# Para crear la columna "Puntos_extras", podemos utilizar el método apply para aplicar una función a la columna "Nota". Esta función debe multiplicar 0.4 por el valor de la nota de cada estudiante y colocar el resultado en nuestra nueva columna:

# %%
# INICIO DEL EJERCICIO ALUMNOS
# IMPORTANTO DATOS
#RETOMANDO ARCHIVO
import pandas as pd
url_ejerc_alumnos = 'https://gist.githubusercontent.com/ahcamachod/807a2c1cf6c19108b2b701ea1791ab45/raw/fb84f8b2d8917a89de26679eccdbc8f9c1d2e933/alumnos.csv'
datos_ejerc_alumnos = pd.read_csv(url_ejerc_alumnos)

# %%
datos_ejerc_alumnos.head()
# Out:
#     Nombre  Edad  Nota Aprobado
# 0  Alberto    20   7.5     True
# 1      Ana    18   NaN    False
# 2   Camila    27   2.5    False
# 3    David    18   5.0    False
# 4    Brian    21  10.0     True

# %%
datos_ejerc_alumnos.tail()
# Out:
#     Nombre  Edad  Nota   Aprobado
# 13  Miriam    25   9.0       True
# 14   Pablo    37   NaN      False
# 15  Milena    29   7.0       True
# 16   Lucas    33   NaN      False
# 17   Nadia    34   8.0  Verdadero

# %%
#Para crear la columna "Puntos_extras", podemos utilizar el método apply para aplicar una función a la columna "Nota". Esta función debe multiplicar 0.4 por el valor de la nota de cada estudiante y colocar el resultado en nuestra nueva columna:
datos_ejerc_alumnos['Puntos_extras'] = datos_ejerc_alumnos['Nota'].apply(lambda x: x*0.4)

# %%
datos_ejerc_alumnos.tail()
# Out:
#     Nombre  Edad  Nota   Aprobado  Puntos_extras
# 13  Miriam    25   9.0       True            3.6
# 14   Pablo    37   NaN      False            NaN
# 15  Milena    29   7.0       True            2.8
# 16   Lucas    33   NaN      False            NaN
# 17   Nadia    34   8.0  Verdadero            3.2

# %%
#creando la coluimna notas finales
datos_ejerc_alumnos['Notas_finales'] = datos_ejerc_alumnos['Nota'] + datos_ejerc_alumnos['Puntos_extras']

# %%
datos_ejerc_alumnos.head()
# Out:
#     Nombre  Edad  Nota Aprobado  Puntos_extras  Notas_finales
# 0  Alberto    20   7.5     True            3.0           10.5
# 1      Ana    18   NaN    False            NaN            NaN
# 2   Camila    27   2.5    False            1.0            3.5
# 3    David    18   5.0    False            2.0            7.0
# 4    Brian    21  10.0     True            4.0           14.0

# %%
#creando columna Aprobados finales con funcion lambda y applydonde lee si la nota es 7 o mayor de siete
datos_ejerc_alumnos['Aprobado_final'] = datos_ejerc_alumnos['Notas_finales'].apply(lambda x: True if x >= 7.0 else False)

# %%
datos_ejerc_alumnos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Nombre          18 non-null     object
#  1   Edad            18 non-null     int64
#  2   Nota            12 non-null     float64
#  3   Aprobado        18 non-null     object
#  4   Puntos_extras   12 non-null     float64
#  5   Notas_finales   12 non-null     float64
#  6   Aprobado_final  18 non-null     bool
# dtypes: bool(1), float64(3), int64(1), object(2)
# memory usage: 1014.0+ bytes

# %%
datos_ejerc_alumnos
# Out:
#       Nombre  Edad  Nota   Aprobado  Puntos_extras  Notas_finales  \
# 0    Alberto    20   7.5       True           3.00          10.50
# 1        Ana    18   NaN      False            NaN            NaN
# 2     Camila    27   2.5      False           1.00           3.50
# 3      David    18   5.0      False           2.00           7.00
# 4      Brian    21  10.0       True           4.00          14.00
# 5      Bruna    23   NaN      False            NaN            NaN
# 6    Daniela    21   7.0       True           2.80           9.80
# 7     Carlos    19   6.0      False           2.40           8.40
# 8     Alicia    35   5.6      False           2.24           7.84
# 9     Victor    28   NaN      False            NaN            NaN
# 10    Danilo    21   NaN      False            NaN            NaN
# 11   Ignacio    24   4.5      False           1.80           6.30
# 12  Stephany    26  10.0       True           4.00          14.00
# ...

# %% [markdown]
# 4.0Realiza una selección y verifica qué estudiantes no habían sido aprobados anteriormente, pero ahora fueron aprobados después de sumar los puntos extras.

# %%
#Realiza una selección y verifica qué estudiantes no habían sido aprobados anteriormente, pero ahora fueron aprobados después de sumar los puntos extras.
#datos_ejerc_alumnos.query('Aprobado == False & Aprobado_final == True')
datos_ejerc_alumnos.query('Aprobado == "False" & Aprobado_final == True')
# Out:
#    Nombre  Edad  Nota Aprobado  Puntos_extras  Notas_finales  Aprobado_final
# 3   David    18   5.0    False           2.00           7.00            True
# 7  Carlos    19   6.0    False           2.40           8.40            True
# 8  Alicia    35   5.6    False           2.24           7.84            True

# %%
#Realiza una selección y verifica qué estudiantes no habían sido aprobados anteriormente, pero ahora fueron aprobados después de sumar los puntos extras.
#selecciondatos_ejerc_alumnos = (datos_ejerc_alumnos['Aprobado'] == False) & (datos_ejerc_alumnos['Aprobado_final'] == True)
selecciondatos_ejerc_alumnos = (datos_ejerc_alumnos['Aprobado'] == "False") & (datos_ejerc_alumnos['Aprobado_final'] == True)
datos_ejerc_alumnos[selecciondatos_ejerc_alumnos ]
# Out:
#    Nombre  Edad  Nota Aprobado  Puntos_extras  Notas_finales  Aprobado_final
# 3   David    18   5.0    False           2.00           7.00            True
# 7  Carlos    19   6.0    False           2.40           8.40            True
# 8  Alicia    35   5.6    False           2.24           7.84            True
